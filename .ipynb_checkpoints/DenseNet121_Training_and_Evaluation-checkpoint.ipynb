# %% [markdown]
# # Contents
#
#       Training
#            - Imports
#            - Mounting Drive
#            - Getting paths and directories, setting global variables
#            - Pre-processing and Data Augmentation
#            - Previewing Data Augmentation
#            - Functions to calculate metrics
#            - Model build using transfer learning architecture.
#            - Function to graph model metrics
#            - Train and Save Model
#            - Training and Validation Metrics
#       Testing
#           - Make Predictions
#           - Visualize Predictions
#           - Evaluate Model
#           - In-Depth Metrics Report
#           - Confusion Matrix
#           - ROC Curve
#           - Precision-Recall Curve
#           - Compare Metrics at Different Classification Thresholds
#           - Optimal Cutoffs

# %% [markdown]
# **Imports**

# %%
import os, shutil, PIL, keras
import matplotlib.pyplot as plt
import tensorflow as tf
import keras.backend as K
import random
import numpy as np
import cv2

from pathlib import Path
from keras import layers, models, optimizers, regularizers

from keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing import image
from keras.applications.resnet50 import ResNet50
from keras.applications.densenet import DenseNet121
from keras.applications.nasnet import NASNetMobile
from keras.applications import InceptionResNetV2
from keras.models import Model, Input, Sequential,load_model
from keras.layers import AveragePooling2D, Dense, Dropout, Conv2D, MaxPool2D, Flatten
from keras.callbacks import Callback, ModelCheckpoint
from keras.wrappers.scikit_learn import KerasClassifier


from sklearn import metrics

import matplotlib.image as mpimg

import itertools
from sklearn import metrics

import sklearn.metrics
import math
import pandas as pd


from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from matplotlib import pyplot

# %% [markdown]
# **Mounting Drive**

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !pip install pyyaml h5py  # Required to save models in HDF5 format
# Out:
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (3.13)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (2.10.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from h5py) (1.15.0)
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.6/dist-packages (from h5py) (1.18.5)

# %% [markdown]
# **Getting paths and directories, setting global variables**

# %%
IMAGE_SIZE = (224, 224)
TRAIN_BATCH_SIZE = 32
VAL_BATCH_SIZE = 64
NUM_EPOCHS = 35
TRANSFER_MODEL = DenseNet121(input_shape=(IMAGE_SIZE[0],IMAGE_SIZE[1],3), include_top=False)
#percent of layers that will be trainable from original model
PERCENT_TRAINABLE = 0.5


TRAIN_DIR = '/content/drive/My Drive/CVT/data/train'
VAL_DIR = '/content/drive/My Drive/CVT/data/validation'
TEST_DIR = '/content/drive/My Drive/CVT/data/test'
#hold-out set
TEST2_DIR = '/content/drive/My Drive/CVT/HO-data'

NUM_TRAIN_SAMPLES = len(os.listdir(TRAIN_DIR + "/COVID")) + len(os.listdir(TRAIN_DIR + "/NonCOVID"))
NUM_VAL_SAMPLES = len(os.listdir(VAL_DIR + "/COVID")) + len(os.listdir(VAL_DIR + "/NonCOVID"))

# %% [markdown]
# **Pre-processing and Data Augmentation**

# %%
def preprocess_data():
    train_datagen = ImageDataGenerator(
        rescale=1./255,
        rotation_range=10,
        width_shift_range=0.05,
        height_shift_range=0.05,
        brightness_range=[0.5, 1.0],
        shear_range=0.05,
        zoom_range=0.15,
        horizontal_flip=True,
        # vertical_flip=True,
        # fill_mode="constant",
        # cval=255
    )

    test_datagen = ImageDataGenerator(rescale=1./255)

    test_generator = test_datagen.flow_from_directory(
        TEST_DIR,
        target_size=IMAGE_SIZE,
        shuffle=False,
        class_mode='binary'
    )

    train_generator = train_datagen.flow_from_directory(
          TRAIN_DIR,
          target_size=IMAGE_SIZE,
          batch_size=TRAIN_BATCH_SIZE,
          class_mode='binary'
       )

    validation_generator = test_datagen.flow_from_directory(
        VAL_DIR,
        target_size=IMAGE_SIZE,
        batch_size=VAL_BATCH_SIZE,
        class_mode='binary'
    )
    
    test_generator2 = test_datagen.flow_from_directory(
        TEST2_DIR,
        target_size=IMAGE_SIZE,
        shuffle=False,
        class_mode='binary'
    )

    return (train_generator, validation_generator, test_generator, test_generator2)

def add_noise_contrast(img):
    VARIABILITY = 25
    deviation = VARIABILITY*random.random()
    noise = np.random.normal(0, deviation, img.shape)
    img += noise
    np.clip(img, 0., 255.)
    return img

def augment(img):
    if np.random.random() < 0.3:
      kernel = np.ones((5, 5), np.uint8)
      img = cv2.erode(img, kernel, iterations=1)
    if np.random.random() < 0.3:
      kernel = np.ones((5, 5), np.uint8)
      img = cv2.dilate(img, kernel, iterations=1) 
    # return add_noise_contrast(img)
    return img

# %% [markdown]
# **Previewing Data Augmentation**

# %%
def test_augmentation():
    datagen = ImageDataGenerator(
        rescale=1./255,
        rotation_range=10,
        width_shift_range=0.04,
        height_shift_range=0.04,
        brightness_range=[0.4, 1.0],
        shear_range=0.05,
        zoom_range=0.2,
        horizontal_flip=True,
        # vertical_flip=True,
        # fill_mode="constant",
        # cval=255

    )
  
    fnames_covid = [os.path.join(TRAIN_DIR, 'COVID', fname) for fname in os.listdir(os.path.join(TRAIN_DIR, 'COVID'))]
    fnames_noncovid = [os.path.join(TRAIN_DIR, 'NonCOVID', fname) for fname in os.listdir(os.path.join(TRAIN_DIR, 'NonCOVID'))]
    fnames = fnames_covid + fnames_noncovid
    for r in range(3):
      img_path = fnames[random.randint(0, len(fnames) - 1)]
      print(img_path)

      img = image.load_img(img_path, target_size=IMAGE_SIZE)
      x = image.img_to_array(img)
      x = x.reshape((1,) + x.shape)
      print(x.shape)
      i = 0
      for batch in datagen.flow(x, batch_size=1):
          plt.figure(i)
          imgplot = plt.imshow(image.array_to_img(batch[0]))
          i += 1
          if (i % 3 == 0):
            break
      plt.show()

test_augmentation()
# Out:
# /content/drive/My Drive/CVT/data/train/COVID/mosmed_img99.jpg
# (1, 224, 224, 3)
# /content/drive/My Drive/CVT/data/train/NonCOVID/img75.jpg
# (1, 224, 224, 3)
# /content/drive/My Drive/CVT/data/train/COVID/Covid (282).png
# (1, 224, 224, 3)

# %% [markdown]
# **Functions to calculate metrics**

# %%
def f1(y_true, y_pred): 
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

def f2(y_true, y_pred): 
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f2_val = (5 * precision * recall) / (4 * precision + recall+K.epsilon())
    return f2_val


def sensitivity(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    return true_positives / (possible_positives + K.epsilon())

def specificity(y_true, y_pred):
    true_negatives = K.sum(K.round(K.clip((1-y_true) * (1-y_pred), 0, 1)))
    possible_negatives = K.sum(K.round(K.clip(1-y_true, 0, 1)))
    return true_negatives / (possible_negatives + K.epsilon())

def balanced_acc(y_true, y_pred):
    return (sensitivity(y_true, y_pred) + specificity(y_true, y_pred))/2

# %% [markdown]
# **Model build using transfer learning architecture.**

# %%
def build_transfer():
  IMG_SHAPE = (224, 224, 3)

  for index,layer in enumerate(TRANSFER_MODEL.layers):
    if index < len(TRANSFER_MODEL.layers) * PERCENT_TRAINABLE: 
      layer.trainable = False 
    else:
      layer.trainable = True 
      

  X = layers.Flatten()(TRANSFER_MODEL.output)    
  X = layers.Dense(64)(X)
  X = layers.Activation('relu')(X)
  X = layers.Dropout(0.5)(X)                   
  X = layers.Dense (1, activation='sigmoid')(X)           

  model = Model(TRANSFER_MODEL.input, X) 

  model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=[
                       tf.keras.metrics.BinaryAccuracy(threshold=0.5),
                       balanced_acc, 
                       f1, 
                       f2,
                       tf.keras.metrics.Recall(name="recall"), 
                       specificity,
                       tf.keras.metrics.Precision(name='precision'),
                       tf.keras.metrics.AUC(name="auc")])
  return model

# %% [markdown]
# **Function to graph model metrics**

# %%
def graph_metrics(history):
  metrics_list = list(history.history.keys())
  num_metrics = int(len(metrics_list)/2)

  fig, axs = plt.subplots(math.ceil(num_metrics/2), 2, figsize=(20, 35))

  epochs = range(1, NUM_EPOCHS+1)

  for i in range(num_metrics):
    train_metric = history.history[metrics_list[i]]
    val_metric = history.history[metrics_list[i + num_metrics]]
    row = int(i/2)
    col = 1 * (i % 2 != 0)
    axs[row, col].plot(epochs, train_metric, label='Training ' + metrics_list[i])
    axs[row, col].plot(epochs, val_metric, label='Validation' + metrics_list[i])
    axs[row, col].set_title(metrics_list[i])
    axs[row, col].legend()
  plt.show()

# %% [markdown]
# **Train and Save Model**

# %%
def train(model, train_generator, validation_generator):
    history = model.fit(
                    train_generator,
                    steps_per_epoch=NUM_TRAIN_SAMPLES//TRAIN_BATCH_SIZE,
                    epochs=NUM_EPOCHS,
                    validation_data=validation_generator,
                    validation_steps=NUM_VAL_SAMPLES//VAL_BATCH_SIZE,
                    callbacks = [tf.keras.callbacks.ReduceLROnPlateau(patience=5)]
            )
    return history

# %%
model = build_transfer()
train_generator, validation_generator, test_generator, test2_generator = preprocess_data()
history = train(model, train_generator, validation_generator)
model.save("my_h5_model.h5")

# # else:
# dependencies = {
#     'balanced_acc': balanced_acc,
#     'f1' : f1,
#     'f2' : f2,
#     'specificity' : specificity,
#     'sensitivity' : sensitivity

# }
# model = load_model("my_h5_model.h5", custom_objects=dependencies)
# Out:
# Found 690 images belonging to 2 classes.
# Found 3217 images belonging to 2 classes.
# Found 690 images belonging to 2 classes.
# Found 361 images belonging to 2 classes.
# Epoch 1/35
# 100/100 [==============================] - 80s 803ms/step - loss: 0.7886 - binary_accuracy: 0.6703 - balanced_acc: 0.6684 - f1: 0.5815 - f2: 0.5409 - recall: 0.5123 - specificity: 0.8123 - precision: 0.7065 - auc: 0.7448 - val_loss: 0.4372 - val_binary_accuracy: 0.8234 - val_balanced_acc: 0.8231 - val_f1: 0.7976 - val_f2: 0.7608 - val_recall: 0.7344 - val_specificity: 0.9070 - val_precision: 0.8750 - val_auc: 0.8928
# Epoch 2/35
# 100/100 [==============================] - 77s 767ms/step - loss: 0.5102 - binary_accuracy: 0.7636 - balanced_acc: 0.7705 - f1: 0.7598 - f2: 0.7854 - recall: 0.8019 - specificity: 0.7331 - precision: 0.7250 - auc: 0.8367 - val_loss: 0.3645 - val_binary_accuracy: 0.8188 - val_balanced_acc: 0.8176 - val_f1: 0.7987 - val_f2: 0.7811 - val_recall: 0.7682 - val_specificity: 0.8647 - val_precision: 0.8345 - val_auc: 0.9178
# Epoch 3/35
# 100/100 [==============================] - 76s 763ms/step - loss: 0.4919 - binary_accuracy: 0.7771 - balanced_acc: 0.7836 - f1: 0.7744 - f2: 0.8093 - recall: 0.8332 - specificity: 0.7277 - precision: 0.7320 - auc: 0.8411 - val_loss: 0.3800 - val_binary_accuracy: 0.8375 - val_balanced_acc: 0.8410 - val_f1: 0.8296 - val_f2: 0.8503 - val_recall: 0.8662 - val_specificity: 0.8163 - val_precision: 0.8019 - val_auc: 0.9339
# Epoch 4/35
# 100/100 [==============================] - 76s 764ms/step - loss: 0.4553 - binary_accuracy: 0.7987 - balanced_acc: 0.8049 - f1: 0.7924 - f2: 0.8220 - recall: 0.8448 - specificity: 0.7630 - precision: 0.7566 - auc: 0.8685 - val_loss: 0.4610 - val_binary_accuracy: 0.7578 - val_balanced_acc: 0.7662 - val_f1: 0.7856 - val_f2: 0.8702 - val_recall: 0.9373 - val_specificity: 0.5942 - val_precision: 0.6762 - val_auc: 0.9002
# Epoch 5/35
# 100/100 [==============================] - 77s 768ms/step - loss: 0.4264 - binary_accuracy: 0.8223 - balanced_acc: 0.8316 - f1: 0.8189 - f2: 0.8478 - recall: 0.8652 - specificity: 0.7908 - precision: 0.7809 - auc: 0.8875 - val_loss: 0.2901 - val_binary_accuracy: 0.8703 - val_balanced_acc: 0.8715 - val_f1: 0.8641 - val_f2: 0.8711 - val_recall: 0.8738 - val_specificity: 0.8663 - val_precision: 0.8539 - val_auc: 0.9551
# Epoch 6/35
# 100/100 [==============================] - 77s 768ms/step - loss: 0.4169 - binary_accuracy: 0.8374 - balanced_acc: 0.8452 - f1: 0.8347 - f2: 0.8570 - recall: 0.8703 - specificity: 0.8135 - precision: 0.8021 - auc: 0.8966 - val_loss: 0.2707 - val_binary_accuracy: 0.8828 - val_balanced_acc: 0.8787 - val_f1: 0.8662 - val_f2: 0.8409 - val_recall: 0.8284 - val_specificity: 0.9316 - val_precision: 0.9161 - val_auc: 0.9620
# Epoch 7/35
# 100/100 [==============================] - 76s 764ms/step - loss: 0.4060 - binary_accuracy: 0.8380 - balanced_acc: 0.8453 - f1: 0.8337 - f2: 0.8663 - recall: 0.8892 - specificity: 0.7977 - precision: 0.7919 - auc: 0.9031 - val_loss: 0.3326 - val_binary_accuracy: 0.8500 - val_balanced_acc: 0.8492 - val_f1: 0.8385 - val_f2: 0.8388 - val_recall: 0.8400 - val_specificity: 0.8586 - val_precision: 0.8400 - val_auc: 0.9418
# Epoch 8/35
# 100/100 [==============================] - 77s 768ms/step - loss: 0.3766 - binary_accuracy: 0.8537 - balanced_acc: 0.8602 - f1: 0.8489 - f2: 0.8743 - recall: 0.8890 - specificity: 0.8249 - precision: 0.8173 - auc: 0.9166 - val_loss: 0.5009 - val_binary_accuracy: 0.7859 - val_balanced_acc: 0.7928 - val_f1: 0.7823 - val_f2: 0.8169 - val_recall: 0.8423 - val_specificity: 0.7417 - val_precision: 0.7361 - val_auc: 0.8777
# Epoch 9/35
# 100/100 [==============================] - 77s 771ms/step - loss: 0.3573 - binary_accuracy: 0.8653 - balanced_acc: 0.8725 - f1: 0.8601 - f2: 0.8827 - recall: 0.8962 - specificity: 0.8438 - precision: 0.8315 - auc: 0.9280 - val_loss: 0.2691 - val_binary_accuracy: 0.9031 - val_balanced_acc: 0.8999 - val_f1: 0.8935 - val_f2: 0.8717 - val_recall: 0.8581 - val_specificity: 0.9417 - val_precision: 0.9319 - val_auc: 0.9612
# Epoch 10/35
# 100/100 [==============================] - 77s 770ms/step - loss: 0.3585 - binary_accuracy: 0.8609 - balanced_acc: 0.8652 - f1: 0.8529 - f2: 0.8759 - recall: 0.8941 - specificity: 0.8357 - precision: 0.8254 - auc: 0.9260 - val_loss: 0.2710 - val_binary_accuracy: 0.8844 - val_balanced_acc: 0.8774 - val_f1: 0.8614 - val_f2: 0.8204 - val_recall: 0.8013 - val_specificity: 0.9591 - val_precision: 0.9453 - val_auc: 0.9633
# Epoch 11/35
# 100/100 [==============================] - 77s 769ms/step - loss: 0.3453 - binary_accuracy: 0.8675 - balanced_acc: 0.8735 - f1: 0.8630 - f2: 0.8851 - recall: 0.8970 - specificity: 0.8437 - precision: 0.8349 - auc: 0.9281 - val_loss: 0.3891 - val_binary_accuracy: 0.8609 - val_balanced_acc: 0.8578 - val_f1: 0.8428 - val_f2: 0.8134 - val_recall: 0.7961 - val_specificity: 0.9199 - val_precision: 0.8996 - val_auc: 0.9439
# Epoch 12/35
# 100/100 [==============================] - 77s 768ms/step - loss: 0.3553 - binary_accuracy: 0.8587 - balanced_acc: 0.8648 - f1: 0.8524 - f2: 0.8772 - recall: 0.8949 - specificity: 0.8320 - precision: 0.8216 - auc: 0.9273 - val_loss: 0.2907 - val_binary_accuracy: 0.8828 - val_balanced_acc: 0.8770 - val_f1: 0.8666 - val_f2: 0.8353 - val_recall: 0.8203 - val_specificity: 0.9375 - val_precision: 0.9262 - val_auc: 0.9580
# Epoch 13/35
# 100/100 [==============================] - 77s 771ms/step - loss: 0.3345 - binary_accuracy: 0.8725 - balanced_acc: 0.8788 - f1: 0.8663 - f2: 0.8938 - recall: 0.9119 - specificity: 0.8413 - precision: 0.8330 - auc: 0.9327 - val_loss: 0.2485 - val_binary_accuracy: 0.9016 - val_balanced_acc: 0.8998 - val_f1: 0.8914 - val_f2: 0.8800 - val_recall: 0.8742 - val_specificity: 0.9265 - val_precision: 0.9135 - val_auc: 0.9653
# Epoch 14/35
# 100/100 [==============================] - 77s 770ms/step - loss: 0.3267 - binary_accuracy: 0.8719 - balanced_acc: 0.8782 - f1: 0.8689 - f2: 0.8976 - recall: 0.9168 - specificity: 0.8356 - precision: 0.8295 - auc: 0.9358 - val_loss: 0.2601 - val_binary_accuracy: 0.9062 - val_balanced_acc: 0.9032 - val_f1: 0.8950 - val_f2: 0.8683 - val_recall: 0.8529 - val_specificity: 0.9547 - val_precision: 0.9457 - val_auc: 0.9626
# Epoch 15/35
# 100/100 [==============================] - 77s 767ms/step - loss: 0.3189 - binary_accuracy: 0.8857 - balanced_acc: 0.8919 - f1: 0.8812 - f2: 0.9059 - recall: 0.9208 - specificity: 0.8583 - precision: 0.8496 - auc: 0.9425 - val_loss: 0.3309 - val_binary_accuracy: 0.8813 - val_balanced_acc: 0.8766 - val_f1: 0.8643 - val_f2: 0.8326 - val_recall: 0.8146 - val_specificity: 0.9401 - val_precision: 0.9248 - val_auc: 0.9540
# Epoch 16/35
# 100/100 [==============================] - 77s 766ms/step - loss: 0.3281 - binary_accuracy: 0.8710 - balanced_acc: 0.8773 - f1: 0.8670 - f2: 0.9015 - recall: 0.9268 - specificity: 0.8256 - precision: 0.8223 - auc: 0.9314 - val_loss: 0.2965 - val_binary_accuracy: 0.8828 - val_balanced_acc: 0.8838 - val_f1: 0.8737 - val_f2: 0.8923 - val_recall: 0.9106 - val_specificity: 0.8612 - val_precision: 0.8514 - val_auc: 0.9562
# Epoch 17/35
# 100/100 [==============================] - 77s 769ms/step - loss: 0.3189 - binary_accuracy: 0.8706 - balanced_acc: 0.8770 - f1: 0.8667 - f2: 0.8995 - recall: 0.9235 - specificity: 0.8282 - precision: 0.8237 - auc: 0.9393 - val_loss: 0.3139 - val_binary_accuracy: 0.8719 - val_balanced_acc: 0.8704 - val_f1: 0.8628 - val_f2: 0.8687 - val_recall: 0.8787 - val_specificity: 0.8676 - val_precision: 0.8562 - val_auc: 0.9500
# Epoch 18/35
# 100/100 [==============================] - 77s 770ms/step - loss: 0.3145 - binary_accuracy: 0.8791 - balanced_acc: 0.8850 - f1: 0.8757 - f2: 0.9104 - recall: 0.9360 - specificity: 0.8318 - precision: 0.8293 - auc: 0.9439 - val_loss: 0.3486 - val_binary_accuracy: 0.8672 - val_balanced_acc: 0.8748 - val_f1: 0.8642 - val_f2: 0.9009 - val_recall: 0.9264 - val_specificity: 0.8206 - val_precision: 0.8147 - val_auc: 0.9426
# Epoch 19/35
# 100/100 [==============================] - 77s 768ms/step - loss: 0.2622 - binary_accuracy: 0.9055 - balanced_acc: 0.9120 - f1: 0.9003 - f2: 0.9274 - recall: 0.9467 - specificity: 0.8750 - precision: 0.8655 - auc: 0.9613 - val_loss: 0.2590 - val_binary_accuracy: 0.9031 - val_balanced_acc: 0.9013 - val_f1: 0.8895 - val_f2: 0.8717 - val_recall: 0.8620 - val_specificity: 0.9417 - val_precision: 0.9242 - val_auc: 0.9666
# Epoch 20/35
# 100/100 [==============================] - 77s 768ms/step - loss: 0.2352 - binary_accuracy: 0.9199 - balanced_acc: 0.9260 - f1: 0.9124 - f2: 0.9306 - recall: 0.9420 - specificity: 0.9065 - precision: 0.8937 - auc: 0.9694 - val_loss: 0.2675 - val_binary_accuracy: 0.9141 - val_balanced_acc: 0.9127 - val_f1: 0.9035 - val_f2: 0.8893 - val_recall: 0.8796 - val_specificity: 0.9449 - val_precision: 0.9326 - val_auc: 0.9640
# Epoch 21/35
# 100/100 [==============================] - 77s 772ms/step - loss: 0.2351 - binary_accuracy: 0.9190 - balanced_acc: 0.9256 - f1: 0.9137 - f2: 0.9355 - recall: 0.9467 - specificity: 0.8989 - precision: 0.8888 - auc: 0.9679 - val_loss: 0.2814 - val_binary_accuracy: 0.9062 - val_balanced_acc: 0.9020 - val_f1: 0.8956 - val_f2: 0.8766 - val_recall: 0.8675 - val_specificity: 0.9394 - val_precision: 0.9291 - val_auc: 0.9628
# Epoch 22/35
# 100/100 [==============================] - 77s 767ms/step - loss: 0.2192 - binary_accuracy: 0.9334 - balanced_acc: 0.9362 - f1: 0.9280 - f2: 0.9435 - recall: 0.9540 - specificity: 0.9171 - precision: 0.9091 - auc: 0.9737 - val_loss: 0.3039 - val_binary_accuracy: 0.9094 - val_balanced_acc: 0.9070 - val_f1: 0.8970 - val_f2: 0.8708 - val_recall: 0.8528 - val_specificity: 0.9593 - val_precision: 0.9480 - val_auc: 0.9633
# Epoch 23/35
# 100/100 [==============================] - 77s 765ms/step - loss: 0.2126 - binary_accuracy: 0.9391 - balanced_acc: 0.9426 - f1: 0.9358 - f2: 0.9514 - recall: 0.9601 - specificity: 0.9220 - precision: 0.9150 - auc: 0.9764 - val_loss: 0.2860 - val_binary_accuracy: 0.9109 - val_balanced_acc: 0.9090 - val_f1: 0.9013 - val_f2: 0.8811 - val_recall: 0.8662 - val_specificity: 0.9495 - val_precision: 0.9384 - val_auc: 0.9680
# Epoch 24/35
# 100/100 [==============================] - 76s 763ms/step - loss: 0.2140 - binary_accuracy: 0.9284 - balanced_acc: 0.9331 - f1: 0.9233 - f2: 0.9431 - recall: 0.9567 - specificity: 0.9077 - precision: 0.8981 - auc: 0.9735 - val_loss: 0.2985 - val_binary_accuracy: 0.9125 - val_balanced_acc: 0.9085 - val_f1: 0.9011 - val_f2: 0.8768 - val_recall: 0.8624 - val_specificity: 0.9555 - val_precision: 0.9449 - val_auc: 0.9654
# Epoch 25/35
# 100/100 [==============================] - 77s 767ms/step - loss: 0.2164 - binary_accuracy: 0.9350 - balanced_acc: 0.9395 - f1: 0.9306 - f2: 0.9487 - recall: 0.9601 - specificity: 0.9161 - precision: 0.9075 - auc: 0.9739 - val_loss: 0.3455 - val_binary_accuracy: 0.9047 - val_balanced_acc: 0.9006 - val_f1: 0.8937 - val_f2: 0.8648 - val_recall: 0.8467 - val_specificity: 0.9542 - val_precision: 0.9442 - val_auc: 0.9591
# Epoch 26/35
# 100/100 [==============================] - 77s 766ms/step - loss: 0.2095 - binary_accuracy: 0.9369 - balanced_acc: 0.9406 - f1: 0.9327 - f2: 0.9484 - recall: 0.9581 - specificity: 0.9207 - precision: 0.9125 - auc: 0.9753 - val_loss: 0.3478 - val_binary_accuracy: 0.9078 - val_balanced_acc: 0.9061 - val_f1: 0.8964 - val_f2: 0.8676 - val_recall: 0.8482 - val_specificity: 0.9624 - val_precision: 0.9519 - val_auc: 0.9609
# Epoch 27/35
# 100/100 [==============================] - 76s 761ms/step - loss: 0.2083 - binary_accuracy: 0.9347 - balanced_acc: 0.9393 - f1: 0.9310 - f2: 0.9472 - recall: 0.9555 - specificity: 0.9189 - precision: 0.9107 - auc: 0.9770 - val_loss: 0.3470 - val_binary_accuracy: 0.9062 - val_balanced_acc: 0.9044 - val_f1: 0.8949 - val_f2: 0.8650 - val_recall: 0.8469 - val_specificity: 0.9625 - val_precision: 0.9524 - val_auc: 0.9620
# Epoch 28/35
# 100/100 [==============================] - 76s 762ms/step - loss: 0.2137 - binary_accuracy: 0.9363 - balanced_acc: 0.9398 - f1: 0.9294 - f2: 0.9500 - recall: 0.9648 - specificity: 0.9125 - precision: 0.9063 - auc: 0.9750 - val_loss: 0.3659 - val_binary_accuracy: 0.9047 - val_balanced_acc: 0.9010 - val_f1: 0.8914 - val_f2: 0.8578 - val_recall: 0.8367 - val_specificity: 0.9650 - val_precision: 0.9544 - val_auc: 0.9596
# Epoch 29/35
# 100/100 [==============================] - 77s 766ms/step - loss: 0.2085 - binary_accuracy: 0.9375 - balanced_acc: 0.9405 - f1: 0.9332 - f2: 0.9465 - recall: 0.9553 - specificity: 0.9242 - precision: 0.9156 - auc: 0.9778 - val_loss: 0.3594 - val_binary_accuracy: 0.9016 - val_balanced_acc: 0.8994 - val_f1: 0.8889 - val_f2: 0.8598 - val_recall: 0.8400 - val_specificity: 0.9567 - val_precision: 0.9438 - val_auc: 0.9588
# Epoch 30/35
# 100/100 [==============================] - 77s 766ms/step - loss: 0.2106 - binary_accuracy: 0.9268 - balanced_acc: 0.9306 - f1: 0.9222 - f2: 0.9391 - recall: 0.9508 - specificity: 0.9092 - precision: 0.9000 - auc: 0.9739 - val_loss: 0.3232 - val_binary_accuracy: 0.9125 - val_balanced_acc: 0.9087 - val_f1: 0.8996 - val_f2: 0.8757 - val_recall: 0.8620 - val_specificity: 0.9563 - val_precision: 0.9446 - val_auc: 0.9640
# Epoch 31/35
# 100/100 [==============================] - 76s 764ms/step - loss: 0.1922 - binary_accuracy: 0.9441 - balanced_acc: 0.9470 - f1: 0.9404 - f2: 0.9541 - recall: 0.9621 - specificity: 0.9295 - precision: 0.9227 - auc: 0.9798 - val_loss: 0.3157 - val_binary_accuracy: 0.9094 - val_balanced_acc: 0.9083 - val_f1: 0.9010 - val_f2: 0.8718 - val_recall: 0.8502 - val_specificity: 0.9629 - val_precision: 0.9560 - val_auc: 0.9673
# Epoch 32/35
# 100/100 [==============================] - 76s 764ms/step - loss: 0.1992 - binary_accuracy: 0.9441 - balanced_acc: 0.9467 - f1: 0.9384 - f2: 0.9518 - recall: 0.9613 - specificity: 0.9315 - precision: 0.9231 - auc: 0.9798 - val_loss: 0.3526 - val_binary_accuracy: 0.9094 - val_balanced_acc: 0.9066 - val_f1: 0.8968 - val_f2: 0.8703 - val_recall: 0.8523 - val_specificity: 0.9595 - val_precision: 0.9478 - val_auc: 0.9602
# Epoch 33/35
# 100/100 [==============================] - 77s 769ms/step - loss: 0.2069 - binary_accuracy: 0.9350 - balanced_acc: 0.9384 - f1: 0.9297 - f2: 0.9429 - recall: 0.9501 - specificity: 0.9235 - precision: 0.9154 - auc: 0.9759 - val_loss: 0.3546 - val_binary_accuracy: 0.9094 - val_balanced_acc: 0.9054 - val_f1: 0.8988 - val_f2: 0.8694 - val_recall: 0.8510 - val_specificity: 0.9596 - val_precision: 0.9519 - val_auc: 0.9606
# Epoch 34/35
# 100/100 [==============================] - 77s 768ms/step - loss: 0.2039 - binary_accuracy: 0.9338 - balanced_acc: 0.9370 - f1: 0.9292 - f2: 0.9445 - recall: 0.9539 - specificity: 0.9178 - precision: 0.9095 - auc: 0.9770 - val_loss: 0.3511 - val_binary_accuracy: 0.9078 - val_balanced_acc: 0.9073 - val_f1: 0.8974 - val_f2: 0.8732 - val_recall: 0.8548 - val_specificity: 0.9562 - val_precision: 0.9453 - val_auc: 0.9611
# Epoch 35/35
# 100/100 [==============================] - 76s 762ms/step - loss: 0.2050 - binary_accuracy: 0.9385 - balanced_acc: 0.9425 - f1: 0.9340 - f2: 0.9509 - recall: 0.9613 - specificity: 0.9214 - precision: 0.9125 - auc: 0.9762 - val_loss: 0.3660 - val_binary_accuracy: 0.9016 - val_balanced_acc: 0.8972 - val_f1: 0.8861 - val_f2: 0.8549 - val_recall: 0.8367 - val_specificity: 0.9586 - val_precision: 0.9472 - val_auc: 0.9583

# %% [markdown]
# **Training and Validation Metrics**

# %%
graph_metrics(history)
# Out:
# TRAINING AND VALIDATION METRICS

# %% [markdown]
# **Make Predictions**

# %%
# test_generator = test2_generator
test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(
        TEST_DIR,
        target_size=IMAGE_SIZE,
        shuffle=False,
        class_mode='binary'
    )
y_true = 1 - test_generator.classes
prediction = (1 - model.predict(test_generator))
y_pred = [1 * (x[0]>=.65) for x in prediction]
# Out:
# Found 690 images belonging to 2 classes.

# %% [markdown]
# **Visualize Predictions**

# %%
index = 0
while index < len(prediction):
  probability = prediction[index]
  image_path =  TEST_DIR + "/" +test_generator.filenames[index]
  image = mpimg.imread(image_path, 0)
  #BGR TO RGB conversion using CV2
  image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
  pixels = np.array(image)
  plt.imshow(pixels)
  print("prob:{}".format(probability))
  print(test_generator.filenames[index])
    
  plt.title('%.2f' % ((probability)*100) + '% COVID')
  plt.show()
  index+=random.randint(50,150)
# Out:
# prob:[0.8915546]
# COVID/2019-novel-Coronavirus-severe-adult-respiratory-dist_2020_International-Jour-p3-89%1.png
# prob:[1.]
# COVID/Covid (263).png
# prob:[1.]
# COVID/Covid (78).png
# prob:[0.7976525]
# COVID/img602.jpg
# prob:[0.1002878]
# NonCOVID/35%2.jpg
# prob:[0.04351151]
# NonCOVID/Non-Covid (1115).png
# prob:[0.01765311]
# NonCOVID/Non-Covid (866).png
# prob:[0.37305707]
# NonCOVID/img44.jpg

# %% [markdown]
# **Evaluate Model**

# %%
print(metrics.classification_report(y_true, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.88      0.89       325
#            1       0.90      0.91      0.90       365
#
#     accuracy                           0.90       690
#    macro avg       0.90      0.89      0.90       690
# weighted avg       0.90      0.90      0.90       690

# %% [markdown]
# **In-Depth Metrics Report**
# see https://en.wikipedia.org/wiki/Confusion_matrix

# %%
def matrix_metrix(y_true, y_pred):
    CM = metrics.confusion_matrix(y_true , y_pred)
    TN = CM[0][0]
    FN = CM[1][0] 
    TP = CM[1][1]
    FP = CM[0][1]
    Population = TN+FN+TP+FP
    Prevalence = round( (TP+FP) / Population,3)
    Accuracy   = round( (TP+TN) / Population,3)
    Precision  = round( TP / (TP+FP),3 )
    NPV        = round( TN / (TN+FN),3 )
    FDR        = round( FP / (TP+FP),3 )
    FOR        = round( FN / (TN+FN),3 ) 
    check_Pos  = Precision + FDR
    check_Neg  = NPV + FOR
    Recall     = round( TP / (TP+FN),3 )
    FPR        = round( FP / (TN+FP),3 )
    Specificity = 1 - FPR
    FNR        = round( FN / (TP+FN),3)
    TNR        = round( TN / (TN+FP),3 ) 
    check_Pos2 = Recall + FNR
    check_Neg2 = FPR + TNR
    LRPos      = round( Recall/FPR,3 ) 
    LRNeg      = round( FNR / TNR ,3 )
    DOR        = round( LRPos/LRNeg)
    F1         = round ( 2 * ((Precision*Recall)/(Precision+Recall)),4)
    F2      = round ( (1+2**2)*((Precision*Recall)/((2**2 * Precision)+ Recall)) ,4)
    MCC        = round ( ((TP*TN)-(FP*FN))/math.sqrt((TP+FP)*(TP+FN)*(TN+FP)*(TN+FN))  ,4)
    BM         = Recall+TNR-1
    MK         = Precision+NPV-1
    AUC = round(roc_auc_score(y_true, y_pred),3)

    met_dict = {
   'TP': TP,'TN':TN,'FP':FP,  'FN':FN,   'Prevalence':Prevalence, 
     'Accuracy':Accuracy,   'Precision':Precision,'Recall':Recall,
    'F1':F1,  'F2':F2, 'AUC':AUC, 'NPV':NPV,'FPR':FPR,
   'TNR':Specificity,  'FNR':FNR, 'TNR':TNR,'FDR':FDR,'FOR':FOR,'check_Pos':check_Pos,
   'check_Neg':check_Neg,  'check_Pos2':check_Pos2, 'check_Neg2':check_Neg2, 'LR+':LRPos,
    'LR-':LRNeg,  'DOR':DOR, 'MCC':MCC,'BM':BM,'MK':MK 
   }  

    return met_dict

for key, value in matrix_metrix(y_true, y_pred).items(): 
    print("{:<10} {:<10}".format(key, value))
# Out:
# TP         331
# TN         287
# FP         38
# FN         34
# Prevalence 0.535
# Accuracy   0.896
# Precision  0.897
# Recall     0.907
# F1         0.902
# F2         0.905
# AUC        0.895
# NPV        0.894
# FPR        0.117
# TNR        0.883
# FNR        0.093
# FDR        0.103
# FOR        0.106
# check_Pos  1.0
# check_Neg  1.0
# check_Pos2 1.0
# check_Neg2 1.0
# LR+        7.752
# LR-        0.105
# DOR        74.0
# MCC        0.7905
# BM         0.79
# MK         0.7909999999999999

# %% [markdown]
# **Confusion Matrix**

# %%
def plot_confusion_matrix(cm, classes,
    normalize=False,
    title='Confusion matrix',
    cmap=plt.cm.Blues):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')
    
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt), fontsize= 20,
                 horizontalalignment="center",
                 color="yellow" if cm[i, j] > thresh else "red")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()
cm=metrics.confusion_matrix(y_true,y_pred)
plot_confusion_matrix(cm=cm, classes=['NON-COVID', 'COVID'], title='Confusion Matrix')
plot_confusion_matrix(cm=cm, classes=['NON-COVID', 'COVID'], title='Confusion Matrix', normalize=True)
# Out:
# Confusion matrix, without normalization
# Normalized confusion matrix

# %% [markdown]
# **ROC Curve**

# %%
#ROC Implementation
def get_roc_curve(y_true, y_pred):
  print("AUC: " + str(metrics.roc_auc_score(y_true, y_pred)))
  fpr, tpr, thresholds = roc_curve(y_true, y_pred)
  # print(fpr)
  # print(tpr)
  pyplot.plot(fpr, tpr, linestyle='--', label='ROC curve')
  pyplot.xlabel('False Positive Rate')
  pyplot.ylabel('True Positive Rate')
  pyplot.legend()
  pyplot.show()
  
get_roc_curve(y_true, prediction)
# Out:
# AUC: 0.9670979978925185

# %% [markdown]
# **Precision-Recall Curve**

# %%
def get_pr_curve(y_true, y_pred):
  print("Average Precision: " +  str(sklearn.metrics.average_precision_score(y_true, y_pred)))
  precision, recall, thresholds = sklearn.metrics.precision_recall_curve(y_true, y_pred)
  pyplot.plot(recall, precision, linestyle='--', label='Precision versus Recall')
  pyplot.xlabel('Recall')
  pyplot.ylabel('Precision')
  pyplot.legend()
  pyplot.show()

get_pr_curve(y_true, prediction)
# Out:
# Average Precision: 0.9712537195378962

# %% [markdown]
# **Compare Metrics at Different Classification Thresholds**

# %%
thresholds = [round(i * .01, 2) for i in range(1,100)]
def metric_against_thresholds(metric):
    vals = []
    for t in thresholds:
      y_pred = [1 * (x>=t) for x in prediction]
    
      vals.append(float(matrix_metrix(y_true, y_pred)[metric]))

    return vals

def plot_metrics_against_thresholds(desired_metrics= ["Accuracy","Precision", "Recall", "F1", "F2", "AUC"]):
  pyplot.figure(figsize=(14,14))
  pyplot.xlabel("Classification Threshold", fontsize=15)
  pyplot.ylabel("Metric Value", fontsize=15)
  for i in range(len(desired_metrics)):
    pyplot.plot(thresholds, metric_against_thresholds(desired_metrics[i]), lw=2, label=desired_metrics[i])
  pyplot.legend(title="Metrics", fontsize='large')
  pyplot.grid()
  pyplot.show()
plot_metrics_against_thresholds()

# %% [markdown]
# **Optimal Cutoffs**
#
# see https://www.hindawi.com/journals/cmmm/2017/3762651/

# %%
def get_optimal_cutoffs():
  TN, FP, FN, TP = metrics.confusion_matrix(y_true,y_pred).ravel()
  sensitivity = round( TP / (TP+FN),2 )
  specificity = round( TN / (TN+FP),2 )
  auc = metrics.roc_auc_score(y_true, y_pred)

  youden = sensitivity + specificity - 1
  print("youden: " + str(youden))

  closest_to_01 =  np.sqrt(((1 - sensitivity)**2) + ((1 - specificity)**2))
  print("Closest to (0,1): " + str(np.around(closest_to_01, decimals = 3)))

  concordance_probability = sensitivity * specificity
  print("Concordance Probability: " + str((np.around(concordance_probability, decimals = 3))))

  index_of_union = np.abs(sensitivity - auc) + np.abs(specificity - auc)
  print("Index of Union: " + str((np.around(index_of_union, decimals = 3))))

get_optimal_cutoffs()
# Out:
# youden: 0.79
# Closest to (0,1): 0.15
# Concordance Probability: 0.801
# Index of Union: 0.03
