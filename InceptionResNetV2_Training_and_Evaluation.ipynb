# %% [markdown]
# # Contents
#
#       Training
#            - Imports
#            - Mounting Drive
#            - Getting paths and directories, setting global variables
#            - Pre-processing and Data Augmentation
#            - Previewing Data Augmentation
#            - Functions to calculate metrics
#            - Model build using transfer learning architecture.
#            - Function to graph model metrics
#            - Train and Save Model
#            - Training and Validation Metrics
#       Testing
#           - Make Predictions
#           - Visualize Predictions
#           - Evaluate Model
#           - In-Depth Metrics Report
#           - Confusion Matrix
#           - ROC Curve
#           - Precision-Recall Curve
#           - Compare Metrics at Different Classification Thresholds
#           - Optimal Cutoffs

# %% [markdown]
# **Imports**

# %%
import os, shutil, PIL, keras
import matplotlib.pyplot as plt
import tensorflow as tf
import keras.backend as K
import random
import numpy as np
import cv2

from pathlib import Path
from keras import layers, models, optimizers, regularizers

from keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing import image
from keras.applications.resnet50 import ResNet50
from keras.applications.densenet import DenseNet121
from keras.applications.nasnet import NASNetMobile
from keras.applications import InceptionResNetV2
from keras.models import Model, Input, Sequential,load_model
from keras.layers import AveragePooling2D, Dense, Dropout, Conv2D, MaxPool2D, Flatten
from keras.callbacks import Callback, ModelCheckpoint
from keras.wrappers.scikit_learn import KerasClassifier


from sklearn import metrics

import matplotlib.image as mpimg

import itertools
from sklearn import metrics

import sklearn.metrics
import math
import pandas as pd


from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from matplotlib import pyplot

# %% [markdown]
# **Mounting Drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !pip install pyyaml h5py  # Required to save models in HDF5 format
# Out:
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (3.13)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (2.10.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from h5py) (1.15.0)
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.6/dist-packages (from h5py) (1.18.5)

# %% [markdown]
# **Getting paths and directories, setting global variables**

# %%
IMAGE_SIZE = (224, 224)
TRAIN_BATCH_SIZE = 32
VAL_BATCH_SIZE = 64
NUM_EPOCHS = 50
TRANSFER_MODEL = InceptionResNetV2(input_shape=(IMAGE_SIZE[0],IMAGE_SIZE[1],3), include_top=False)
#percent of layers that will be trainable from original model
PERCENT_TRAINABLE = 0.5


TRAIN_DIR = '/content/drive/My Drive/CVT/data/train'
VAL_DIR = '/content/drive/My Drive/CVT/data/validation'
TEST_DIR = '/content/drive/My Drive/CVT/data/test'
#hold-out set
TEST2_DIR = '/content/drive/My Drive/CVT/HO-data'

NUM_TRAIN_SAMPLES = len(os.listdir(TRAIN_DIR + "/COVID")) + len(os.listdir(TRAIN_DIR + "/NonCOVID"))
NUM_VAL_SAMPLES = len(os.listdir(VAL_DIR + "/COVID")) + len(os.listdir(VAL_DIR + "/NonCOVID"))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_resnet_v2/inception_resnet_v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 219062272/219055592 [==============================] - 2s 0us/step

# %% [markdown]
# **Pre-processing and Data Augmentation**

# %%
def preprocess_data():
    train_datagen = ImageDataGenerator(
        rescale=1./255,
        rotation_range=10,
        width_shift_range=0.05,
        height_shift_range=0.05,
        brightness_range=[0.5, 1.0],
        shear_range=0.05,
        zoom_range=0.15,
        horizontal_flip=True,
        # vertical_flip=True,
        # fill_mode="constant",
        # cval=255
    )

    test_datagen = ImageDataGenerator(rescale=1./255)

    test_generator = test_datagen.flow_from_directory(
        TEST_DIR,
        target_size=IMAGE_SIZE,
        shuffle=False,
        class_mode='binary'
    )

    train_generator = train_datagen.flow_from_directory(
          TRAIN_DIR,
          target_size=IMAGE_SIZE,
          batch_size=TRAIN_BATCH_SIZE,
          class_mode='binary'
       )

    validation_generator = test_datagen.flow_from_directory(
        VAL_DIR,
        target_size=IMAGE_SIZE,
        batch_size=VAL_BATCH_SIZE,
        class_mode='binary'
    )
    
    test_generator2 = test_datagen.flow_from_directory(
        TEST2_DIR,
        target_size=IMAGE_SIZE,
        shuffle=False,
        class_mode='binary'
    )

    return (train_generator, validation_generator, test_generator, test_generator2)

def add_noise_contrast(img):
    VARIABILITY = 25
    deviation = VARIABILITY*random.random()
    noise = np.random.normal(0, deviation, img.shape)
    img += noise
    np.clip(img, 0., 255.)
    return img

def augment(img):
    if np.random.random() < 0.3:
      kernel = np.ones((5, 5), np.uint8)
      img = cv2.erode(img, kernel, iterations=1)
    if np.random.random() < 0.3:
      kernel = np.ones((5, 5), np.uint8)
      img = cv2.dilate(img, kernel, iterations=1) 
    # return add_noise_contrast(img)
    return img

# %% [markdown]
# **Previewing Data Augmentation**

# %%
def test_augmentation():
    datagen = ImageDataGenerator(
        rescale=1./255,
        rotation_range=10,
        width_shift_range=0.04,
        height_shift_range=0.04,
        brightness_range=[0.4, 1.0],
        shear_range=0.05,
        zoom_range=0.2,
        horizontal_flip=True,
        # vertical_flip=True,
        # fill_mode="constant",
        # cval=255

    )
  
    fnames_covid = [os.path.join(TRAIN_DIR, 'COVID', fname) for fname in os.listdir(os.path.join(TRAIN_DIR, 'COVID'))]
    fnames_noncovid = [os.path.join(TRAIN_DIR, 'NonCOVID', fname) for fname in os.listdir(os.path.join(TRAIN_DIR, 'NonCOVID'))]
    fnames = fnames_covid + fnames_noncovid
    for r in range(3):
      img_path = fnames[random.randint(0, len(fnames) - 1)]
      print(img_path)

      img = image.load_img(img_path, target_size=IMAGE_SIZE)
      x = image.img_to_array(img)
      x = x.reshape((1,) + x.shape)
      print(x.shape)
      i = 0
      for batch in datagen.flow(x, batch_size=1):
          plt.figure(i)
          imgplot = plt.imshow(image.array_to_img(batch[0]))
          i += 1
          if (i % 3 == 0):
            break
      plt.show()

test_augmentation()
# Out:
# /content/drive/My Drive/CVT/data/train/COVID/img38.jpg
# (1, 224, 224, 3)
# /content/drive/My Drive/CVT/data/train/COVID/2020.02.24.20027052-p8-73%3.png
# (1, 224, 224, 3)
# /content/drive/My Drive/CVT/data/train/COVID/Covid (1072).png
# (1, 224, 224, 3)

# %% [markdown]
# **Functions to calculate metrics**

# %%
def f1(y_true, y_pred): 
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

def f2(y_true, y_pred): 
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f2_val = (5 * precision * recall) / (4 * precision + recall+K.epsilon())
    return f2_val


def sensitivity(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    return true_positives / (possible_positives + K.epsilon())

def specificity(y_true, y_pred):
    true_negatives = K.sum(K.round(K.clip((1-y_true) * (1-y_pred), 0, 1)))
    possible_negatives = K.sum(K.round(K.clip(1-y_true, 0, 1)))
    return true_negatives / (possible_negatives + K.epsilon())

def balanced_acc(y_true, y_pred):
    return (sensitivity(y_true, y_pred) + specificity(y_true, y_pred))/2

# %% [markdown]
# **Model build using transfer learning architecture.**

# %%
def build_transfer():
  IMG_SHAPE = (224, 224, 3)

  for index,layer in enumerate(TRANSFER_MODEL.layers):
    if index < len(TRANSFER_MODEL.layers) * PERCENT_TRAINABLE: 
      layer.trainable = False 
    else:
      layer.trainable = True 
      

  X = layers.Flatten()(TRANSFER_MODEL.output)    
  X = layers.Dense(64)(X)
  X = layers.Activation('relu')(X)
  X = layers.Dropout(0.5)(X)                   
  X = layers.Dense (1, activation='sigmoid')(X)           

  model = Model(TRANSFER_MODEL.input, X) 

  model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=[
                       tf.keras.metrics.BinaryAccuracy(threshold=0.5),
                       balanced_acc, 
                       f1, 
                       f2,
                       tf.keras.metrics.Recall(name="recall"), 
                       specificity,
                       tf.keras.metrics.Precision(name='precision'),
                       tf.keras.metrics.AUC(name="auc")])
  return model

# %% [markdown]
# **Function to graph model metrics**

# %%
def graph_metrics(history):
  metrics_list = list(history.history.keys())
  num_metrics = int(len(metrics_list)/2)

  fig, axs = plt.subplots(math.ceil(num_metrics/2), 2, figsize=(20, 35))

  epochs = range(1, NUM_EPOCHS+1)

  for i in range(num_metrics-1):
    train_metric = history.history[metrics_list[i]]
    val_metric = history.history[metrics_list[i + num_metrics]]
    row = int(i/2)
    col = 1 * (i % 2 != 0)
    axs[row, col].plot(epochs, train_metric, label='Training ' + metrics_list[i])
    axs[row, col].plot(epochs, val_metric, label='Validation' + metrics_list[i])
    axs[row, col].set_title(metrics_list[i])
    axs[row, col].legend()
  plt.show()

# %% [markdown]
# **Train and Save Model**

# %%
def train(model, train_generator, validation_generator):
    history = model.fit(
                    train_generator,
                    steps_per_epoch=NUM_TRAIN_SAMPLES//TRAIN_BATCH_SIZE,
                    epochs=NUM_EPOCHS,
                    validation_data=validation_generator,
                    validation_steps=NUM_VAL_SAMPLES//VAL_BATCH_SIZE,
                    callbacks = [tf.keras.callbacks.ReduceLROnPlateau(patience=5)]
            )
    return history

# %%
model = build_transfer()
train_generator, validation_generator, test_generator, test2_generator = preprocess_data()
history = train(model, train_generator, validation_generator)
model.save("saved_models/inceptionresnetv2")
# Out:
# Found 690 images belonging to 2 classes.
# Found 3217 images belonging to 2 classes.
# Found 690 images belonging to 2 classes.
# Found 361 images belonging to 2 classes.
# Epoch 1/50
# 100/100 [==============================] - 107s 1s/step - loss: 0.9082 - binary_accuracy: 0.5881 - balanced_acc: 0.5761 - f1: 0.4579 - f2: 0.4172 - recall: 0.4024 - specificity: 0.7531 - precision: 0.5927 - auc: 0.6082 - val_loss: 60.7377 - val_binary_accuracy: 0.5328 - val_balanced_acc: 0.5000 - val_f1: 0.0000e+00 - val_f2: 0.0000e+00 - val_recall: 0.0000e+00 - val_specificity: 1.0000 - val_precision: 0.0000e+00 - val_auc: 0.4775
# Epoch 2/50
# 100/100 [==============================] - 97s 969ms/step - loss: 0.6468 - binary_accuracy: 0.6411 - balanced_acc: 0.6353 - f1: 0.5404 - f2: 0.5014 - recall: 0.4833 - specificity: 0.7872 - precision: 0.6624 - auc: 0.6531 - val_loss: 0.6525 - val_binary_accuracy: 0.5391 - val_balanced_acc: 0.5361 - val_f1: 0.4701 - val_f2: 0.4499 - val_recall: 0.4422 - val_specificity: 0.6335 - val_precision: 0.5154 - val_auc: 0.6117
# Epoch 3/50
# 100/100 [==============================] - 97s 969ms/step - loss: 0.5746 - binary_accuracy: 0.7422 - balanced_acc: 0.7381 - f1: 0.6865 - f2: 0.6456 - recall: 0.6223 - specificity: 0.8521 - precision: 0.7872 - auc: 0.7789 - val_loss: 0.5173 - val_binary_accuracy: 0.7406 - val_balanced_acc: 0.7263 - val_f1: 0.6206 - val_f2: 0.5172 - val_recall: 0.4669 - val_specificity: 0.9862 - val_precision: 0.9658 - val_auc: 0.8080
# Epoch 4/50
# 100/100 [==============================] - 97s 967ms/step - loss: 0.4968 - binary_accuracy: 0.7834 - balanced_acc: 0.7801 - f1: 0.7334 - f2: 0.6853 - recall: 0.6571 - specificity: 0.9010 - precision: 0.8484 - auc: 0.8299 - val_loss: 0.7087 - val_binary_accuracy: 0.6625 - val_balanced_acc: 0.6422 - val_f1: 0.4372 - val_f2: 0.3332 - val_recall: 0.2951 - val_specificity: 0.9964 - val_precision: 0.9890 - val_auc: 0.7529
# Epoch 5/50
# 100/100 [==============================] - 98s 983ms/step - loss: 0.4724 - binary_accuracy: 0.7940 - balanced_acc: 0.7896 - f1: 0.7434 - f2: 0.6894 - recall: 0.6569 - specificity: 0.9190 - precision: 0.8759 - auc: 0.8590 - val_loss: 0.9457 - val_binary_accuracy: 0.5844 - val_balanced_acc: 0.5617 - val_f1: 0.2159 - val_f2: 0.1489 - val_recall: 0.1221 - val_specificity: 1.0000 - val_precision: 1.0000 - val_auc: 0.6987
# Epoch 6/50
# 100/100 [==============================] - 96s 957ms/step - loss: 0.5267 - binary_accuracy: 0.8085 - balanced_acc: 0.8089 - f1: 0.7698 - f2: 0.7261 - recall: 0.6934 - specificity: 0.9151 - precision: 0.8730 - auc: 0.8767 - val_loss: 115536.2500 - val_binary_accuracy: 0.5344 - val_balanced_acc: 0.5000 - val_f1: 0.0000e+00 - val_f2: 0.0000e+00 - val_recall: 0.0000e+00 - val_specificity: 1.0000 - val_precision: 0.0000e+00 - val_auc: 0.5239
# Epoch 7/50
# 100/100 [==============================] - 96s 958ms/step - loss: 0.5681 - binary_accuracy: 0.7815 - balanced_acc: 0.7812 - f1: 0.7320 - f2: 0.6838 - recall: 0.6500 - specificity: 0.9037 - precision: 0.8518 - auc: 0.8299 - val_loss: 0.9813 - val_binary_accuracy: 0.5188 - val_balanced_acc: 0.5000 - val_f1: 0.0000e+00 - val_f2: 0.0000e+00 - val_recall: 0.0000e+00 - val_specificity: 1.0000 - val_precision: 0.0000e+00 - val_auc: 0.5044
# Epoch 8/50
# 100/100 [==============================] - 96s 957ms/step - loss: 0.4635 - binary_accuracy: 0.8129 - balanced_acc: 0.8138 - f1: 0.7712 - f2: 0.7180 - recall: 0.6773 - specificity: 0.9387 - precision: 0.9017 - auc: 0.8584 - val_loss: 0.4839 - val_binary_accuracy: 0.8344 - val_balanced_acc: 0.8304 - val_f1: 0.8110 - val_f2: 0.7772 - val_recall: 0.7558 - val_specificity: 0.9043 - val_precision: 0.8774 - val_auc: 0.8605
# Epoch 9/50
# 100/100 [==============================] - 99s 990ms/step - loss: 0.4089 - binary_accuracy: 0.8430 - balanced_acc: 0.8430 - f1: 0.8129 - f2: 0.7724 - recall: 0.7457 - specificity: 0.9365 - precision: 0.9047 - auc: 0.8923 - val_loss: 0.8508 - val_binary_accuracy: 0.8109 - val_balanced_acc: 0.7991 - val_f1: 0.7704 - val_f2: 0.7197 - val_recall: 0.6936 - val_specificity: 0.9084 - val_precision: 0.8729 - val_auc: 0.8735
# Epoch 10/50
# 100/100 [==============================] - 96s 965ms/step - loss: 0.4064 - binary_accuracy: 0.8436 - balanced_acc: 0.8434 - f1: 0.8126 - f2: 0.7688 - recall: 0.7380 - specificity: 0.9424 - precision: 0.9143 - auc: 0.9036 - val_loss: 0.4829 - val_binary_accuracy: 0.7609 - val_balanced_acc: 0.7477 - val_f1: 0.6655 - val_f2: 0.5651 - val_recall: 0.5149 - val_specificity: 0.9811 - val_precision: 0.9630 - val_auc: 0.8437
# Epoch 11/50
# 100/100 [==============================] - 96s 959ms/step - loss: 0.3835 - binary_accuracy: 0.8662 - balanced_acc: 0.8639 - f1: 0.8410 - f2: 0.8007 - recall: 0.7739 - specificity: 0.9503 - precision: 0.9293 - auc: 0.9273 - val_loss: 0.3261 - val_binary_accuracy: 0.8641 - val_balanced_acc: 0.8599 - val_f1: 0.8433 - val_f2: 0.7984 - val_recall: 0.7742 - val_specificity: 0.9481 - val_precision: 0.9339 - val_auc: 0.9329
# Epoch 12/50
# 100/100 [==============================] - 96s 960ms/step - loss: 0.3490 - binary_accuracy: 0.8462 - balanced_acc: 0.8430 - f1: 0.8128 - f2: 0.7621 - recall: 0.7295 - specificity: 0.9529 - precision: 0.9288 - auc: 0.9324 - val_loss: 0.3759 - val_binary_accuracy: 0.8266 - val_balanced_acc: 0.8186 - val_f1: 0.7939 - val_f2: 0.7368 - val_recall: 0.7059 - val_specificity: 0.9335 - val_precision: 0.9114 - val_auc: 0.9122
# Epoch 13/50
# 100/100 [==============================] - 97s 973ms/step - loss: 0.2989 - binary_accuracy: 0.8791 - balanced_acc: 0.8780 - f1: 0.8587 - f2: 0.8193 - recall: 0.7919 - specificity: 0.9596 - precision: 0.9430 - auc: 0.9406 - val_loss: 0.4478 - val_binary_accuracy: 0.8000 - val_balanced_acc: 0.7855 - val_f1: 0.7228 - val_f2: 0.6249 - val_recall: 0.5738 - val_specificity: 0.9972 - val_precision: 0.9942 - val_auc: 0.9454
# Epoch 14/50
# 100/100 [==============================] - 97s 967ms/step - loss: 0.2835 - binary_accuracy: 0.8879 - balanced_acc: 0.8882 - f1: 0.8716 - f2: 0.8354 - recall: 0.8064 - specificity: 0.9622 - precision: 0.9484 - auc: 0.9446 - val_loss: 0.3310 - val_binary_accuracy: 0.8641 - val_balanced_acc: 0.8605 - val_f1: 0.8428 - val_f2: 0.8123 - val_recall: 0.7905 - val_specificity: 0.9273 - val_precision: 0.9035 - val_auc: 0.9320
# Epoch 15/50
# 100/100 [==============================] - 95s 954ms/step - loss: 0.3058 - binary_accuracy: 0.8681 - balanced_acc: 0.8677 - f1: 0.8444 - f2: 0.8040 - recall: 0.7766 - specificity: 0.9544 - precision: 0.9329 - auc: 0.9399 - val_loss: 1.0802 - val_binary_accuracy: 0.6016 - val_balanced_acc: 0.5930 - val_f1: 0.5392 - val_f2: 0.5145 - val_recall: 0.5049 - val_specificity: 0.6856 - val_precision: 0.5969 - val_auc: 0.6774
# Epoch 16/50
# 100/100 [==============================] - 97s 966ms/step - loss: 0.2811 - binary_accuracy: 0.8892 - balanced_acc: 0.8896 - f1: 0.8694 - f2: 0.8345 - recall: 0.8083 - specificity: 0.9649 - precision: 0.9492 - auc: 0.9479 - val_loss: 0.3288 - val_binary_accuracy: 0.8703 - val_balanced_acc: 0.8679 - val_f1: 0.8549 - val_f2: 0.8371 - val_recall: 0.8267 - val_specificity: 0.9092 - val_precision: 0.8889 - val_auc: 0.9464
# Epoch 17/50
# 100/100 [==============================] - 96s 965ms/step - loss: 0.2278 - binary_accuracy: 0.9042 - balanced_acc: 0.9036 - f1: 0.8868 - f2: 0.8469 - recall: 0.8175 - specificity: 0.9837 - precision: 0.9754 - auc: 0.9646 - val_loss: 0.2699 - val_binary_accuracy: 0.8938 - val_balanced_acc: 0.8872 - val_f1: 0.8752 - val_f2: 0.8422 - val_recall: 0.8231 - val_specificity: 0.9525 - val_precision: 0.9380 - val_auc: 0.9514
# Epoch 18/50
# 100/100 [==============================] - 98s 979ms/step - loss: 0.2148 - binary_accuracy: 0.9137 - balanced_acc: 0.9147 - f1: 0.8997 - f2: 0.8694 - recall: 0.8460 - specificity: 0.9775 - precision: 0.9665 - auc: 0.9697 - val_loss: 0.2361 - val_binary_accuracy: 0.8969 - val_balanced_acc: 0.8926 - val_f1: 0.8804 - val_f2: 0.8363 - val_recall: 0.8098 - val_specificity: 0.9756 - val_precision: 0.9686 - val_auc: 0.9630
# Epoch 19/50
# 100/100 [==============================] - 94s 942ms/step - loss: 0.2047 - binary_accuracy: 0.9143 - balanced_acc: 0.9137 - f1: 0.9014 - f2: 0.8666 - recall: 0.8407 - specificity: 0.9815 - precision: 0.9737 - auc: 0.9714 - val_loss: 0.2271 - val_binary_accuracy: 0.9047 - val_balanced_acc: 0.8974 - val_f1: 0.8854 - val_f2: 0.8453 - val_recall: 0.8272 - val_specificity: 0.9737 - val_precision: 0.9651 - val_auc: 0.9658
# Epoch 20/50
# 100/100 [==============================] - 96s 961ms/step - loss: 0.1868 - binary_accuracy: 0.9162 - balanced_acc: 0.9150 - f1: 0.9008 - f2: 0.8679 - recall: 0.8467 - specificity: 0.9817 - precision: 0.9726 - auc: 0.9761 - val_loss: 0.2692 - val_binary_accuracy: 0.9031 - val_balanced_acc: 0.8970 - val_f1: 0.8861 - val_f2: 0.8403 - val_recall: 0.8146 - val_specificity: 0.9813 - val_precision: 0.9762 - val_auc: 0.9593
# Epoch 21/50
# 100/100 [==============================] - 97s 966ms/step - loss: 0.1868 - binary_accuracy: 0.9203 - balanced_acc: 0.9196 - f1: 0.9080 - f2: 0.8739 - recall: 0.8489 - specificity: 0.9857 - precision: 0.9784 - auc: 0.9755 - val_loss: 0.2839 - val_binary_accuracy: 0.8938 - val_balanced_acc: 0.8900 - val_f1: 0.8778 - val_f2: 0.8352 - val_recall: 0.8098 - val_specificity: 0.9707 - val_precision: 0.9611 - val_auc: 0.9581
# Epoch 22/50
# 100/100 [==============================] - 96s 964ms/step - loss: 0.1996 - binary_accuracy: 0.9171 - balanced_acc: 0.9176 - f1: 0.9040 - f2: 0.8696 - recall: 0.8432 - specificity: 0.9858 - precision: 0.9776 - auc: 0.9731 - val_loss: 0.2605 - val_binary_accuracy: 0.9047 - val_balanced_acc: 0.8967 - val_f1: 0.8841 - val_f2: 0.8427 - val_recall: 0.8239 - val_specificity: 0.9750 - val_precision: 0.9688 - val_auc: 0.9617
# Epoch 23/50
# 100/100 [==============================] - 97s 968ms/step - loss: 0.1752 - binary_accuracy: 0.9234 - balanced_acc: 0.9223 - f1: 0.9102 - f2: 0.8804 - recall: 0.8604 - specificity: 0.9819 - precision: 0.9735 - auc: 0.9779 - val_loss: 0.2827 - val_binary_accuracy: 0.8969 - val_balanced_acc: 0.8918 - val_f1: 0.8806 - val_f2: 0.8374 - val_recall: 0.8100 - val_specificity: 0.9724 - val_precision: 0.9643 - val_auc: 0.9565
# Epoch 24/50
# 100/100 [==============================] - 96s 965ms/step - loss: 0.1769 - binary_accuracy: 0.9246 - balanced_acc: 0.9238 - f1: 0.9115 - f2: 0.8823 - recall: 0.8627 - specificity: 0.9826 - precision: 0.9744 - auc: 0.9783 - val_loss: 0.2867 - val_binary_accuracy: 0.9016 - val_balanced_acc: 0.8961 - val_f1: 0.8855 - val_f2: 0.8423 - val_recall: 0.8197 - val_specificity: 0.9760 - val_precision: 0.9690 - val_auc: 0.9569
# Epoch 25/50
# 100/100 [==============================] - 97s 973ms/step - loss: 0.1669 - binary_accuracy: 0.9262 - balanced_acc: 0.9251 - f1: 0.9147 - f2: 0.8813 - recall: 0.8576 - specificity: 0.9890 - precision: 0.9831 - auc: 0.9799 - val_loss: 0.2830 - val_binary_accuracy: 0.9047 - val_balanced_acc: 0.8986 - val_f1: 0.8858 - val_f2: 0.8453 - val_recall: 0.8233 - val_specificity: 0.9763 - val_precision: 0.9686 - val_auc: 0.9596
# Epoch 26/50
# 100/100 [==============================] - 96s 957ms/step - loss: 0.1607 - binary_accuracy: 0.9309 - balanced_acc: 0.9296 - f1: 0.9214 - f2: 0.8882 - recall: 0.8646 - specificity: 0.9910 - precision: 0.9871 - auc: 0.9817 - val_loss: 0.2812 - val_binary_accuracy: 0.9000 - val_balanced_acc: 0.8962 - val_f1: 0.8836 - val_f2: 0.8447 - val_recall: 0.8194 - val_specificity: 0.9710 - val_precision: 0.9608 - val_auc: 0.9609
# Epoch 27/50
# 100/100 [==============================] - 97s 966ms/step - loss: 0.1636 - binary_accuracy: 0.9303 - balanced_acc: 0.9276 - f1: 0.9185 - f2: 0.8856 - recall: 0.8659 - specificity: 0.9893 - precision: 0.9849 - auc: 0.9810 - val_loss: 0.2756 - val_binary_accuracy: 0.9016 - val_balanced_acc: 0.8938 - val_f1: 0.8826 - val_f2: 0.8367 - val_recall: 0.8133 - val_specificity: 0.9786 - val_precision: 0.9721 - val_auc: 0.9601
# Epoch 28/50
# 100/100 [==============================] - 96s 957ms/step - loss: 0.1652 - binary_accuracy: 0.9290 - balanced_acc: 0.9293 - f1: 0.9192 - f2: 0.8899 - recall: 0.8674 - specificity: 0.9862 - precision: 0.9797 - auc: 0.9795 - val_loss: 0.2869 - val_binary_accuracy: 0.9016 - val_balanced_acc: 0.8985 - val_f1: 0.8854 - val_f2: 0.8459 - val_recall: 0.8182 - val_specificity: 0.9752 - val_precision: 0.9643 - val_auc: 0.9598
# Epoch 29/50
# 100/100 [==============================] - 98s 981ms/step - loss: 0.1663 - binary_accuracy: 0.9284 - balanced_acc: 0.9300 - f1: 0.9189 - f2: 0.8929 - recall: 0.8705 - specificity: 0.9824 - precision: 0.9746 - auc: 0.9804 - val_loss: 0.2705 - val_binary_accuracy: 0.9047 - val_balanced_acc: 0.8991 - val_f1: 0.8883 - val_f2: 0.8471 - val_recall: 0.8227 - val_specificity: 0.9760 - val_precision: 0.9685 - val_auc: 0.9622
# Epoch 30/50
# 100/100 [==============================] - 96s 960ms/step - loss: 0.1604 - binary_accuracy: 0.9268 - balanced_acc: 0.9257 - f1: 0.9154 - f2: 0.8840 - recall: 0.8621 - specificity: 0.9862 - precision: 0.9803 - auc: 0.9809 - val_loss: 0.2829 - val_binary_accuracy: 0.9000 - val_balanced_acc: 0.8941 - val_f1: 0.8827 - val_f2: 0.8407 - val_recall: 0.8179 - val_specificity: 0.9730 - val_precision: 0.9648 - val_auc: 0.9601
# Epoch 31/50
# 100/100 [==============================] - 97s 967ms/step - loss: 0.1620 - binary_accuracy: 0.9268 - balanced_acc: 0.9252 - f1: 0.9142 - f2: 0.8833 - recall: 0.8628 - specificity: 0.9857 - precision: 0.9796 - auc: 0.9817 - val_loss: 0.2872 - val_binary_accuracy: 0.9000 - val_balanced_acc: 0.8950 - val_f1: 0.8847 - val_f2: 0.8446 - val_recall: 0.8218 - val_specificity: 0.9701 - val_precision: 0.9614 - val_auc: 0.9599
# Epoch 32/50
# 100/100 [==============================] - 97s 967ms/step - loss: 0.1677 - binary_accuracy: 0.9234 - balanced_acc: 0.9228 - f1: 0.9098 - f2: 0.8822 - recall: 0.8632 - specificity: 0.9795 - precision: 0.9707 - auc: 0.9801 - val_loss: 0.3036 - val_binary_accuracy: 0.8953 - val_balanced_acc: 0.8924 - val_f1: 0.8783 - val_f2: 0.8397 - val_recall: 0.8158 - val_specificity: 0.9686 - val_precision: 0.9575 - val_auc: 0.9572
# Epoch 33/50
# 100/100 [==============================] - 96s 962ms/step - loss: 0.1744 - binary_accuracy: 0.9250 - balanced_acc: 0.9241 - f1: 0.9132 - f2: 0.8839 - recall: 0.8633 - specificity: 0.9819 - precision: 0.9744 - auc: 0.9788 - val_loss: 0.2929 - val_binary_accuracy: 0.8984 - val_balanced_acc: 0.8932 - val_f1: 0.8829 - val_f2: 0.8436 - val_recall: 0.8206 - val_specificity: 0.9665 - val_precision: 0.9574 - val_auc: 0.9595
# Epoch 34/50
# 100/100 [==============================] - 96s 957ms/step - loss: 0.1531 - binary_accuracy: 0.9347 - balanced_acc: 0.9332 - f1: 0.9257 - f2: 0.8944 - recall: 0.8728 - specificity: 0.9911 - precision: 0.9872 - auc: 0.9834 - val_loss: 0.2951 - val_binary_accuracy: 0.9000 - val_balanced_acc: 0.8946 - val_f1: 0.8810 - val_f2: 0.8392 - val_recall: 0.8167 - val_specificity: 0.9750 - val_precision: 0.9646 - val_auc: 0.9575
# Epoch 35/50
# 100/100 [==============================] - 97s 965ms/step - loss: 0.1627 - binary_accuracy: 0.9290 - balanced_acc: 0.9275 - f1: 0.9177 - f2: 0.8858 - recall: 0.8645 - specificity: 0.9886 - precision: 0.9834 - auc: 0.9808 - val_loss: 0.2748 - val_binary_accuracy: 0.8953 - val_balanced_acc: 0.8916 - val_f1: 0.8820 - val_f2: 0.8419 - val_recall: 0.8164 - val_specificity: 0.9659 - val_precision: 0.9577 - val_auc: 0.9609
# Epoch 36/50
# 100/100 [==============================] - 97s 973ms/step - loss: 0.1692 - binary_accuracy: 0.9256 - balanced_acc: 0.9253 - f1: 0.9135 - f2: 0.8853 - recall: 0.8654 - specificity: 0.9821 - precision: 0.9738 - auc: 0.9796 - val_loss: 0.2836 - val_binary_accuracy: 0.9016 - val_balanced_acc: 0.8975 - val_f1: 0.8866 - val_f2: 0.8447 - val_recall: 0.8208 - val_specificity: 0.9757 - val_precision: 0.9692 - val_auc: 0.9615
# Epoch 37/50
# 100/100 [==============================] - 97s 975ms/step - loss: 0.1617 - binary_accuracy: 0.9294 - balanced_acc: 0.9271 - f1: 0.9175 - f2: 0.8852 - recall: 0.8645 - specificity: 0.9885 - precision: 0.9833 - auc: 0.9815 - val_loss: 0.2910 - val_binary_accuracy: 0.9031 - val_balanced_acc: 0.9000 - val_f1: 0.8896 - val_f2: 0.8524 - val_recall: 0.8295 - val_specificity: 0.9702 - val_precision: 0.9620 - val_auc: 0.9594
# Epoch 38/50
# 100/100 [==============================] - 95s 953ms/step - loss: 0.1653 - binary_accuracy: 0.9243 - balanced_acc: 0.9235 - f1: 0.9124 - f2: 0.8823 - recall: 0.8611 - specificity: 0.9830 - precision: 0.9750 - auc: 0.9802 - val_loss: 0.2752 - val_binary_accuracy: 0.9031 - val_balanced_acc: 0.9015 - val_f1: 0.8879 - val_f2: 0.8522 - val_recall: 0.8289 - val_specificity: 0.9720 - val_precision: 0.9618 - val_auc: 0.9624
# Epoch 39/50
# 100/100 [==============================] - 97s 972ms/step - loss: 0.1589 - binary_accuracy: 0.9284 - balanced_acc: 0.9278 - f1: 0.9164 - f2: 0.8872 - recall: 0.8670 - specificity: 0.9859 - precision: 0.9781 - auc: 0.9824 - val_loss: 0.2960 - val_binary_accuracy: 0.8984 - val_balanced_acc: 0.8923 - val_f1: 0.8783 - val_f2: 0.8384 - val_recall: 0.8185 - val_specificity: 0.9699 - val_precision: 0.9612 - val_auc: 0.9585
# Epoch 40/50
# 100/100 [==============================] - 96s 960ms/step - loss: 0.1587 - binary_accuracy: 0.9266 - balanced_acc: 0.9251 - f1: 0.9148 - f2: 0.8813 - recall: 0.8584 - specificity: 0.9891 - precision: 0.9841 - auc: 0.9812 - val_loss: 0.2925 - val_binary_accuracy: 0.9031 - val_balanced_acc: 0.8979 - val_f1: 0.8858 - val_f2: 0.8458 - val_recall: 0.8215 - val_specificity: 0.9743 - val_precision: 0.9644 - val_auc: 0.9579
# Epoch 41/50
# 100/100 [==============================] - 99s 986ms/step - loss: 0.1577 - binary_accuracy: 0.9303 - balanced_acc: 0.9291 - f1: 0.9192 - f2: 0.8884 - recall: 0.8677 - specificity: 0.9882 - precision: 0.9827 - auc: 0.9833 - val_loss: 0.2962 - val_binary_accuracy: 0.8953 - val_balanced_acc: 0.8928 - val_f1: 0.8794 - val_f2: 0.8388 - val_recall: 0.8137 - val_specificity: 0.9713 - val_precision: 0.9614 - val_auc: 0.9595
# Epoch 42/50
# 100/100 [==============================] - 95s 948ms/step - loss: 0.1585 - binary_accuracy: 0.9231 - balanced_acc: 0.9219 - f1: 0.9098 - f2: 0.8790 - recall: 0.8588 - specificity: 0.9832 - precision: 0.9750 - auc: 0.9821 - val_loss: 0.2585 - val_binary_accuracy: 0.9016 - val_balanced_acc: 0.8975 - val_f1: 0.8852 - val_f2: 0.8473 - val_recall: 0.8233 - val_specificity: 0.9707 - val_precision: 0.9611 - val_auc: 0.9637
# Epoch 43/50
# 100/100 [==============================] - 97s 969ms/step - loss: 0.1614 - binary_accuracy: 0.9265 - balanced_acc: 0.9253 - f1: 0.9137 - f2: 0.8870 - recall: 0.8702 - specificity: 0.9795 - precision: 0.9710 - auc: 0.9815 - val_loss: 0.2900 - val_binary_accuracy: 0.8953 - val_balanced_acc: 0.8933 - val_f1: 0.8814 - val_f2: 0.8425 - val_recall: 0.8146 - val_specificity: 0.9677 - val_precision: 0.9572 - val_auc: 0.9595
# Epoch 44/50
# 100/100 [==============================] - 99s 985ms/step - loss: 0.1604 - binary_accuracy: 0.9278 - balanced_acc: 0.9267 - f1: 0.9172 - f2: 0.8857 - recall: 0.8629 - specificity: 0.9867 - precision: 0.9810 - auc: 0.9816 - val_loss: 0.2972 - val_binary_accuracy: 0.8969 - val_balanced_acc: 0.8946 - val_f1: 0.8834 - val_f2: 0.8458 - val_recall: 0.8191 - val_specificity: 0.9663 - val_precision: 0.9577 - val_auc: 0.9590
# Epoch 45/50
# 100/100 [==============================] - 97s 975ms/step - loss: 0.1642 - binary_accuracy: 0.9268 - balanced_acc: 0.9256 - f1: 0.9148 - f2: 0.8829 - recall: 0.8611 - specificity: 0.9876 - precision: 0.9810 - auc: 0.9808 - val_loss: 0.3021 - val_binary_accuracy: 0.8953 - val_balanced_acc: 0.8906 - val_f1: 0.8776 - val_f2: 0.8378 - val_recall: 0.8146 - val_specificity: 0.9674 - val_precision: 0.9572 - val_auc: 0.9573
# Epoch 46/50
# 100/100 [==============================] - 99s 987ms/step - loss: 0.1684 - binary_accuracy: 0.9281 - balanced_acc: 0.9272 - f1: 0.9161 - f2: 0.8844 - recall: 0.8621 - specificity: 0.9891 - precision: 0.9833 - auc: 0.9810 - val_loss: 0.2995 - val_binary_accuracy: 0.8984 - val_balanced_acc: 0.8915 - val_f1: 0.8807 - val_f2: 0.8376 - val_recall: 0.8146 - val_specificity: 0.9714 - val_precision: 0.9647 - val_auc: 0.9581
# Epoch 47/50
# 100/100 [==============================] - 98s 976ms/step - loss: 0.1538 - binary_accuracy: 0.9316 - balanced_acc: 0.9294 - f1: 0.9210 - f2: 0.8907 - recall: 0.8708 - specificity: 0.9867 - precision: 0.9820 - auc: 0.9842 - val_loss: 0.3044 - val_binary_accuracy: 0.8938 - val_balanced_acc: 0.8873 - val_f1: 0.8753 - val_f2: 0.8322 - val_recall: 0.8098 - val_specificity: 0.9682 - val_precision: 0.9611 - val_auc: 0.9581
# Epoch 48/50
# 100/100 [==============================] - 99s 988ms/step - loss: 0.1614 - binary_accuracy: 0.9281 - balanced_acc: 0.9268 - f1: 0.9166 - f2: 0.8856 - recall: 0.8649 - specificity: 0.9867 - precision: 0.9804 - auc: 0.9816 - val_loss: 0.2588 - val_binary_accuracy: 0.9000 - val_balanced_acc: 0.8947 - val_f1: 0.8828 - val_f2: 0.8433 - val_recall: 0.8206 - val_specificity: 0.9705 - val_precision: 0.9611 - val_auc: 0.9651
# Epoch 49/50
# 100/100 [==============================] - 98s 976ms/step - loss: 0.1633 - binary_accuracy: 0.9287 - balanced_acc: 0.9273 - f1: 0.9167 - f2: 0.8855 - recall: 0.8648 - specificity: 0.9878 - precision: 0.9819 - auc: 0.9811 - val_loss: 0.2872 - val_binary_accuracy: 0.8969 - val_balanced_acc: 0.8910 - val_f1: 0.8783 - val_f2: 0.8364 - val_recall: 0.8140 - val_specificity: 0.9712 - val_precision: 0.9608 - val_auc: 0.9592
# Epoch 50/50
# 100/100 [==============================] - 97s 975ms/step - loss: 0.1589 - binary_accuracy: 0.9278 - balanced_acc: 0.9285 - f1: 0.9188 - f2: 0.8880 - recall: 0.8623 - specificity: 0.9875 - precision: 0.9826 - auc: 0.9823 - val_loss: 0.2838 - val_binary_accuracy: 0.8969 - val_balanced_acc: 0.8944 - val_f1: 0.8826 - val_f2: 0.8424 - val_recall: 0.8146 - val_specificity: 0.9709 - val_precision: 0.9609 - val_auc: 0.9586
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: saved_models/nnmobile2/assets

# %% [markdown]
# **Training and Validation Metrics**

# %%
graph_metrics(history)

# %% [markdown]
# **Make Predictions**

# %%
# test_generator = test2_generator
test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(
        TEST_DIR,
        target_size=IMAGE_SIZE,
        shuffle=False,
        class_mode='binary'
    )
y_true = 1 - test_generator.classes
prediction = (1 - model.predict(test_generator))
y_pred = [1 * (x[0]>=.35) for x in prediction]
# Out:
# Found 690 images belonging to 2 classes.

# %% [markdown]
# **Visualize Predictions**

# %%
index = 0
while index < len(prediction):
  probability = prediction[index]
  image_path =  TEST_DIR + "/" +test_generator.filenames[index]
  image = mpimg.imread(image_path, 0)
  #BGR TO RGB conversion using CV2
  image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
  pixels = np.array(image)
  plt.imshow(pixels)
  print("prob:{}".format(probability))
  print(test_generator.filenames[index])
    
  plt.title('%.2f' % ((probability)*100) + '% COVID')
  plt.show()
  index+=random.randint(50,150)
# Out:
# prob:[0.9997717]
# COVID/2019-novel-Coronavirus-severe-adult-respiratory-dist_2020_International-Jour-p3-89%1.png
# prob:[0.99950475]
# COVID/Covid (11).png
# prob:[0.9506183]
# COVID/Covid (826).png
# prob:[0.4632373]
# COVID/img484.jpg
# prob:[0.00252622]
# NonCOVID/10%2.jpg
# prob:[0.00110173]
# NonCOVID/Non-Covid (1129).png
# prob:[0.]
# NonCOVID/Non-Covid (796).png
# prob:[3.0994415e-06]
# NonCOVID/nor_20_img_6.jpg

# %% [markdown]
# **Evaluate Model**

# %%
print(metrics.classification_report(y_true, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.82      0.88       325
#            1       0.86      0.96      0.91       365
#
#     accuracy                           0.89       690
#    macro avg       0.90      0.89      0.89       690
# weighted avg       0.90      0.89      0.89       690

# %% [markdown]
# **In-Depth Metrics Report**
# see https://en.wikipedia.org/wiki/Confusion_matrix

# %%
def matrix_metrix(y_true, y_pred):
    CM = metrics.confusion_matrix(y_true , y_pred)
    TN = CM[0][0]
    FN = CM[1][0] 
    TP = CM[1][1]
    FP = CM[0][1]
    Population = TN+FN+TP+FP
    Prevalence = round( (TP+FP) / Population,3)
    Accuracy   = round( (TP+TN) / Population,3)
    Precision  = round( TP / (TP+FP),3 )
    NPV        = round( TN / (TN+FN),3 )
    FDR        = round( FP / (TP+FP),3 )
    FOR        = round( FN / (TN+FN),3 ) 
    check_Pos  = Precision + FDR
    check_Neg  = NPV + FOR
    Recall     = round( TP / (TP+FN),3 )
    FPR        = round( FP / (TN+FP),3 )
    Specificity = 1 - FPR
    FNR        = round( FN / (TP+FN),3)
    TNR        = round( TN / (TN+FP),3 ) 
    check_Pos2 = Recall + FNR
    check_Neg2 = FPR + TNR
    LRPos      = round( Recall/FPR,3 ) 
    LRNeg      = round( FNR / TNR ,3 )
    DOR        = round( LRPos/LRNeg)
    F1         = round ( 2 * ((Precision*Recall)/(Precision+Recall)),4)
    F2      = round ( (1+2**2)*((Precision*Recall)/((2**2 * Precision)+ Recall)) ,4)
    MCC        = round ( ((TP*TN)-(FP*FN))/math.sqrt((TP+FP)*(TP+FN)*(TN+FP)*(TN+FN))  ,4)
    BM         = Recall+TNR-1
    MK         = Precision+NPV-1
    AUC = round(roc_auc_score(y_true, y_pred),3)

    met_dict = {
   'TP': TP,'TN':TN,'FP':FP,  'FN':FN,   'Prevalence':Prevalence, 
     'Accuracy':Accuracy,   'Precision':Precision,'Recall':Recall,
    'F1':F1,  'F2':F2, 'AUC':AUC, 'NPV':NPV,'FPR':FPR,
   'TNR':Specificity,  'FNR':FNR, 'TNR':TNR,'FDR':FDR,'FOR':FOR,'check_Pos':check_Pos,
   'check_Neg':check_Neg,  'check_Pos2':check_Pos2, 'check_Neg2':check_Neg2, 'LR+':LRPos,
    'LR-':LRNeg,  'DOR':DOR, 'MCC':MCC,'BM':BM,'MK':MK 
   }  

    return met_dict

for key, value in matrix_metrix(y_true, y_pred).items(): 
    print("{:<10} {:<10}".format(key, value))
# Out:
# TP         351
# TN         266
# FP         59
# FN         14
# Prevalence 0.594
# Accuracy   0.894
# Precision  0.856
# Recall     0.962
# F1         0.9059
# F2         0.9388
# AUC        0.89
# NPV        0.95
# FPR        0.182
# TNR        0.818
# FNR        0.038
# FDR        0.144
# FOR        0.05
# check_Pos  1.0
# check_Neg  1.0
# check_Pos2 1.0
# check_Neg2 1.0
# LR+        5.286
# LR-        0.046
# DOR        115.0
# MCC        0.793
# BM         0.7799999999999998
# MK         0.806

# %% [markdown]
# **Confusion Matrix**

# %%
def plot_confusion_matrix(cm, classes,
    normalize=False,
    title='Confusion matrix',
    cmap=plt.cm.Blues):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')
    
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt), fontsize= 20,
                 horizontalalignment="center",
                 color="yellow" if cm[i, j] > thresh else "red")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()
cm=metrics.confusion_matrix(y_true,y_pred)
plot_confusion_matrix(cm=cm, classes=['NON-COVID', 'COVID'], title='Confusion Matrix')
plot_confusion_matrix(cm=cm, classes=['NON-COVID', 'COVID'], title='Confusion Matrix', normalize=True)
# Out:
# Confusion matrix, without normalization
# Normalized confusion matrix

# %% [markdown]
# **ROC Curve**

# %%
#ROC Implementation
def get_roc_curve(y_true, y_pred):
  print("AUC: " + str(metrics.roc_auc_score(y_true, y_pred)))
  fpr, tpr, thresholds = roc_curve(y_true, y_pred)
  # print(fpr)
  # print(tpr)
  pyplot.plot(fpr, tpr, linestyle='--', label='ROC curve')
  pyplot.xlabel('False Positive Rate')
  pyplot.ylabel('True Positive Rate')
  pyplot.legend()
  pyplot.show()
  
get_roc_curve(y_true, prediction)
# Out:
# AUC: 0.9644004214963119

# %% [markdown]
# **Precision-Recall Curve**

# %%
def get_pr_curve(y_true, y_pred):
  print("Average Precision: " +  str(sklearn.metrics.average_precision_score(y_true, y_pred)))
  precision, recall, thresholds = sklearn.metrics.precision_recall_curve(y_true, y_pred)
  pyplot.plot(recall, precision, linestyle='--', label='Precision versus Recall')
  pyplot.xlabel('Recall')
  pyplot.ylabel('Precision')
  pyplot.legend()
  pyplot.show()

get_pr_curve(y_true, prediction)
# Out:
# Average Precision: 0.9646183154572439

# %% [markdown]
# **Compare Metrics at Different Classification Thresholds**

# %%
thresholds = [round(i * .01, 2) for i in range(1,100)]
def metric_against_thresholds(metric):
    vals = []
    for t in thresholds:
      y_pred = [1 * (x>=t) for x in prediction]
    
      vals.append(float(matrix_metrix(y_true, y_pred)[metric]))

    return vals

def plot_metrics_against_thresholds(desired_metrics= ["Accuracy","Precision", "Recall", "F1", "F2"]):
  pyplot.figure(figsize=(14,14))
  pyplot.xlabel("Classification Threshold", fontsize=15)
  pyplot.ylabel("Metric Value", fontsize=15)
  for i in range(len(desired_metrics)):
    pyplot.plot(thresholds, metric_against_thresholds(desired_metrics[i]), lw=2, label=desired_metrics[i])
  pyplot.legend(title="Metrics", fontsize='large')
  pyplot.grid()
  pyplot.show()
plot_metrics_against_thresholds()

# %% [markdown]
# **Optimal Cutoffs**
#
# see https://www.hindawi.com/journals/cmmm/2017/3762651/

# %%
def get_optimal_cutoffs():
  TN, FP, FN, TP = metrics.confusion_matrix(y_true,y_pred).ravel()
  sensitivity = round( TP / (TP+FN),2 )
  specificity = round( TN / (TN+FP),2 )
  auc = metrics.roc_auc_score(y_true, y_pred)

  youden = sensitivity + specificity - 1
  print("youden: " + str(youden))

  closest_to_01 =  np.sqrt(((1 - sensitivity)**2) + ((1 - specificity)**2))
  print("Closest to (0,1): " + str(np.around(closest_to_01, decimals = 3)))

  concordance_probability = sensitivity * specificity
  print("Concordance Probability: " + str((np.around(concordance_probability, decimals = 3))))

  index_of_union = np.abs(sensitivity - auc) + np.abs(specificity - auc)
  print("Index of Union: " + str((np.around(index_of_union, decimals = 3))))

get_optimal_cutoffs()
# Out:
# youden: 0.7799999999999998
# Closest to (0,1): 0.184
# Concordance Probability: 0.787
# Index of Union: 0.14
