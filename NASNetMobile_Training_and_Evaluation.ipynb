# %% [markdown]
# # Contents
#
#       Training
#            - Imports
#            - Mounting Drive
#            - Getting paths and directories, setting global variables
#            - Pre-processing and Data Augmentation
#            - Previewing Data Augmentation
#            - Functions to calculate metrics
#            - Model build using transfer learning architecture.
#            - Function to graph model metrics
#            - Train and Save Model
#            - Training and Validation Metrics
#       Testing
#           - Make Predictions
#           - Visualize Predictions
#           - Evaluate Model
#           - In-Depth Metrics Report
#           - Confusion Matrix
#           - ROC Curve
#           - Precision-Recall Curve
#           - Compare Metrics at Different Classification Thresholds
#           - Optimal Cutoffs

# %% [markdown]
# **Imports**

# %%
import os, shutil, PIL, keras
import matplotlib.pyplot as plt
import tensorflow as tf
import keras.backend as K
import random
import numpy as np
import cv2

from pathlib import Path
from keras import layers, models, optimizers, regularizers

from keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing import image
from keras.applications.resnet50 import ResNet50
from keras.applications.densenet import DenseNet121
from keras.applications.nasnet import NASNetMobile
from keras.applications import InceptionResNetV2
from keras.models import Model, Input, Sequential,load_model
from keras.layers import AveragePooling2D, Dense, Dropout, Conv2D, MaxPool2D, Flatten
from keras.callbacks import Callback, ModelCheckpoint
from keras.wrappers.scikit_learn import KerasClassifier


from sklearn import metrics

import matplotlib.image as mpimg

import itertools
from sklearn import metrics

import sklearn.metrics
import math
import pandas as pd


from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from matplotlib import pyplot

# %% [markdown]
# **Mounting Drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install pyyaml h5py  # Required to save models in HDF5 format
# Out:
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (3.13)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (2.10.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from h5py) (1.15.0)
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.6/dist-packages (from h5py) (1.18.5)

# %% [markdown]
# **Getting paths and directories, setting global variables**

# %%
IMAGE_SIZE = (224, 224)
TRAIN_BATCH_SIZE = 32
VAL_BATCH_SIZE = 64
NUM_EPOCHS = 50
TRANSFER_MODEL = NASNetMobile(input_shape=(IMAGE_SIZE[0],IMAGE_SIZE[1],3), include_top=False)
#percent of layers that will be trainable from original model
PERCENT_TRAINABLE = 0.5


TRAIN_DIR = '/content/drive/My Drive/CVT/data/train'
VAL_DIR = '/content/drive/My Drive/CVT/data/validation'
TEST_DIR = '/content/drive/My Drive/CVT/data/test'
#hold-out set
TEST2_DIR = '/content/drive/My Drive/CVT/HO-data'

NUM_TRAIN_SAMPLES = len(os.listdir(TRAIN_DIR + "/COVID")) + len(os.listdir(TRAIN_DIR + "/NonCOVID"))
NUM_VAL_SAMPLES = len(os.listdir(VAL_DIR + "/COVID")) + len(os.listdir(VAL_DIR + "/NonCOVID"))

# %% [markdown]
# **Pre-processing and Data Augmentation**

# %%
def preprocess_data():
    train_datagen = ImageDataGenerator(
        rescale=1./255,
        rotation_range=10,
        width_shift_range=0.05,
        height_shift_range=0.05,
        brightness_range=[0.5, 1.0],
        shear_range=0.05,
        zoom_range=0.15,
        horizontal_flip=True,
        # vertical_flip=True,
        # fill_mode="constant",
        # cval=255
    )

    test_datagen = ImageDataGenerator(rescale=1./255)

    test_generator = test_datagen.flow_from_directory(
        TEST_DIR,
        target_size=IMAGE_SIZE,
        shuffle=False,
        class_mode='binary'
    )

    train_generator = train_datagen.flow_from_directory(
          TRAIN_DIR,
          target_size=IMAGE_SIZE,
          batch_size=TRAIN_BATCH_SIZE,
          class_mode='binary'
       )

    validation_generator = test_datagen.flow_from_directory(
        VAL_DIR,
        target_size=IMAGE_SIZE,
        batch_size=VAL_BATCH_SIZE,
        class_mode='binary'
    )
    
    test_generator2 = test_datagen.flow_from_directory(
        TEST2_DIR,
        target_size=IMAGE_SIZE,
        shuffle=False,
        class_mode='binary'
    )

    return (train_generator, validation_generator, test_generator, test_generator2)

def add_noise_contrast(img):
    VARIABILITY = 25
    deviation = VARIABILITY*random.random()
    noise = np.random.normal(0, deviation, img.shape)
    img += noise
    np.clip(img, 0., 255.)
    return img

def augment(img):
    if np.random.random() < 0.3:
      kernel = np.ones((5, 5), np.uint8)
      img = cv2.erode(img, kernel, iterations=1)
    if np.random.random() < 0.3:
      kernel = np.ones((5, 5), np.uint8)
      img = cv2.dilate(img, kernel, iterations=1) 
    # return add_noise_contrast(img)
    return img

# %% [markdown]
# **Previewing Data Augmentation**

# %%
def test_augmentation():
    datagen = ImageDataGenerator(
        rescale=1./255,
        rotation_range=10,
        width_shift_range=0.04,
        height_shift_range=0.04,
        brightness_range=[0.4, 1.0],
        shear_range=0.05,
        zoom_range=0.2,
        horizontal_flip=True,
        # vertical_flip=True,
        # fill_mode="constant",
        # cval=255

    )
  
    fnames_covid = [os.path.join(TRAIN_DIR, 'COVID', fname) for fname in os.listdir(os.path.join(TRAIN_DIR, 'COVID'))]
    fnames_noncovid = [os.path.join(TRAIN_DIR, 'NonCOVID', fname) for fname in os.listdir(os.path.join(TRAIN_DIR, 'NonCOVID'))]
    fnames = fnames_covid + fnames_noncovid
    for r in range(3):
      img_path = fnames[random.randint(0, len(fnames) - 1)]
      print(img_path)

      img = image.load_img(img_path, target_size=IMAGE_SIZE)
      x = image.img_to_array(img)
      x = x.reshape((1,) + x.shape)
      print(x.shape)
      i = 0
      for batch in datagen.flow(x, batch_size=1):
          plt.figure(i)
          imgplot = plt.imshow(image.array_to_img(batch[0]))
          i += 1
          if (i % 3 == 0):
            break
      plt.show()

test_augmentation()
# Out:
# /content/drive/My Drive/CVT/data/train/NonCOVID/Non-Covid (408).png
# (1, 224, 224, 3)
# /content/drive/My Drive/CVT/data/train/NonCOVID/Non-Covid (322).png
# (1, 224, 224, 3)
# /content/drive/My Drive/CVT/data/train/NonCOVID/1306.png
# (1, 224, 224, 3)

# %% [markdown]
# **Functions to calculate metrics**

# %%
def f1(y_true, y_pred): 
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

def f2(y_true, y_pred): 
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f2_val = (5 * precision * recall) / (4 * precision + recall+K.epsilon())
    return f2_val


def sensitivity(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    return true_positives / (possible_positives + K.epsilon())

def specificity(y_true, y_pred):
    true_negatives = K.sum(K.round(K.clip((1-y_true) * (1-y_pred), 0, 1)))
    possible_negatives = K.sum(K.round(K.clip(1-y_true, 0, 1)))
    return true_negatives / (possible_negatives + K.epsilon())

def balanced_acc(y_true, y_pred):
    return (sensitivity(y_true, y_pred) + specificity(y_true, y_pred))/2

# %% [markdown]
# **Model build using transfer learning architecture.**

# %%
def build_transfer():
  IMG_SHAPE = (224, 224, 3)

  for index,layer in enumerate(TRANSFER_MODEL.layers):
    if index < len(TRANSFER_MODEL.layers) * PERCENT_TRAINABLE: 
      layer.trainable = False 
    else:
      layer.trainable = True 
      

  X = layers.Flatten()(TRANSFER_MODEL.output)    
  X = layers.Dense(64)(X)
  X = layers.Activation('relu')(X)
  X = layers.Dropout(0.5)(X)                   
  X = layers.Dense (1, activation='sigmoid')(X)           

  model = Model(TRANSFER_MODEL.input, X) 

  model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=[
                       tf.keras.metrics.BinaryAccuracy(threshold=0.5),
                       balanced_acc, 
                       f1, 
                       f2,
                       tf.keras.metrics.Recall(name="recall"), 
                       specificity,
                       tf.keras.metrics.Precision(name='precision'),
                       tf.keras.metrics.AUC(name="auc")])
  return model

# %% [markdown]
# **Function to graph model metrics**

# %%
def graph_metrics(history):
  metrics_list = list(history.history.keys())
  num_metrics = int(len(metrics_list)/2)

  fig, axs = plt.subplots(math.ceil(num_metrics/2), 2, figsize=(20, 35))

  epochs = range(1, NUM_EPOCHS+1)

  for i in range(num_metrics-1):
    train_metric = history.history[metrics_list[i]]
    val_metric = history.history[metrics_list[i + num_metrics]]
    row = int(i/2)
    col = 1 * (i % 2 != 0)
    axs[row, col].plot(epochs, train_metric, label='Training ' + metrics_list[i])
    axs[row, col].plot(epochs, val_metric, label='Validation' + metrics_list[i])
    axs[row, col].set_title(metrics_list[i])
    axs[row, col].legend()
  plt.show()

# %% [markdown]
# **Train and Save Model**

# %%
def train(model, train_generator, validation_generator):
    history = model.fit(
                    train_generator,
                    steps_per_epoch=NUM_TRAIN_SAMPLES//TRAIN_BATCH_SIZE,
                    epochs=NUM_EPOCHS,
                    validation_data=validation_generator,
                    validation_steps=NUM_VAL_SAMPLES//VAL_BATCH_SIZE,
                    callbacks = [tf.keras.callbacks.ReduceLROnPlateau(patience=5)]
            )
    return history

# %%
model = build_transfer()
train_generator, validation_generator, test_generator, test2_generator = preprocess_data()
history = train(model, train_generator, validation_generator)
model.save("saved_models/nnmobile")
# Out:
# Found 690 images belonging to 2 classes.
# Found 3217 images belonging to 2 classes.
# Found 690 images belonging to 2 classes.
# Found 361 images belonging to 2 classes.
# Epoch 1/50
# 100/100 [==============================] - 141s 1s/step - loss: 0.6827 - binary_accuracy: 0.7309 - balanced_acc: 0.7336 - f1: 0.6874 - f2: 0.6726 - recall: 0.6598 - specificity: 0.7971 - precision: 0.7393 - auc: 0.7847 - val_loss: 0.7513 - val_binary_accuracy: 0.7281 - val_balanced_acc: 0.7347 - val_f1: 0.7327 - val_f2: 0.7689 - val_recall: 0.7914 - val_specificity: 0.6719 - val_precision: 0.6829 - val_auc: 0.7862
# Epoch 2/50
# 100/100 [==============================] - 74s 744ms/step - loss: 0.4400 - binary_accuracy: 0.8176 - balanced_acc: 0.8206 - f1: 0.7942 - f2: 0.7773 - recall: 0.7636 - specificity: 0.8709 - precision: 0.8354 - auc: 0.8889 - val_loss: 22.5500 - val_binary_accuracy: 0.5891 - val_balanced_acc: 0.5638 - val_f1: 0.2283 - val_f2: 0.1596 - val_recall: 0.1358 - val_specificity: 0.9946 - val_precision: 0.9535 - val_auc: 0.5640
# Epoch 3/50
# 100/100 [==============================] - 74s 736ms/step - loss: 0.3587 - binary_accuracy: 0.8581 - balanced_acc: 0.8589 - f1: 0.8371 - f2: 0.8146 - recall: 0.7991 - specificity: 0.9154 - precision: 0.8880 - auc: 0.9233 - val_loss: 26.9106 - val_binary_accuracy: 0.6297 - val_balanced_acc: 0.6292 - val_f1: 0.6250 - val_f2: 0.6482 - val_recall: 0.6656 - val_specificity: 0.5920 - val_precision: 0.5964 - val_auc: 0.6392
# Epoch 4/50
# 100/100 [==============================] - 74s 738ms/step - loss: 0.3360 - binary_accuracy: 0.8716 - balanced_acc: 0.8736 - f1: 0.8535 - f2: 0.8336 - recall: 0.8171 - specificity: 0.9237 - precision: 0.9007 - auc: 0.9339 - val_loss: 796.5271 - val_binary_accuracy: 0.5328 - val_balanced_acc: 0.5017 - val_f1: 0.0067 - val_f2: 0.0043 - val_recall: 0.0033 - val_specificity: 1.0000 - val_precision: 1.0000 - val_auc: 0.5017
# Epoch 5/50
# 100/100 [==============================] - 74s 736ms/step - loss: 0.3256 - binary_accuracy: 0.8703 - balanced_acc: 0.8687 - f1: 0.8502 - f2: 0.8270 - recall: 0.8124 - specificity: 0.9233 - precision: 0.9021 - auc: 0.9426 - val_loss: 271.0561 - val_binary_accuracy: 0.4672 - val_balanced_acc: 0.5000 - val_f1: 0.6339 - val_f2: 0.8103 - val_recall: 1.0000 - val_specificity: 0.0000e+00 - val_precision: 0.4672 - val_auc: 0.5000
# Epoch 6/50
# 100/100 [==============================] - 74s 741ms/step - loss: 0.3090 - binary_accuracy: 0.8757 - balanced_acc: 0.8755 - f1: 0.8582 - f2: 0.8339 - recall: 0.8159 - specificity: 0.9303 - precision: 0.9106 - auc: 0.9440 - val_loss: 686.5267 - val_binary_accuracy: 0.5250 - val_balanced_acc: 0.5000 - val_f1: 0.0000e+00 - val_f2: 0.0000e+00 - val_recall: 0.0000e+00 - val_specificity: 1.0000 - val_precision: 0.0000e+00 - val_auc: 0.5000
# Epoch 7/50
# 100/100 [==============================] - 74s 736ms/step - loss: 0.2011 - binary_accuracy: 0.9143 - balanced_acc: 0.9135 - f1: 0.8993 - f2: 0.8730 - recall: 0.8561 - specificity: 0.9694 - precision: 0.9575 - auc: 0.9747 - val_loss: 329.9898 - val_binary_accuracy: 0.5328 - val_balanced_acc: 0.5015 - val_f1: 0.0057 - val_f2: 0.0036 - val_recall: 0.0033 - val_specificity: 1.0000 - val_precision: 1.0000 - val_auc: 0.5002
# Epoch 8/50
# 100/100 [==============================] - 74s 741ms/step - loss: 0.1867 - binary_accuracy: 0.9228 - balanced_acc: 0.9242 - f1: 0.9126 - f2: 0.8916 - recall: 0.8746 - specificity: 0.9692 - precision: 0.9585 - auc: 0.9785 - val_loss: 118.7961 - val_binary_accuracy: 0.5734 - val_balanced_acc: 0.5518 - val_f1: 0.3324 - val_f2: 0.2632 - val_recall: 0.2323 - val_specificity: 0.8718 - val_precision: 0.6053 - val_auc: 0.5648
# Epoch 9/50
# 100/100 [==============================] - 74s 744ms/step - loss: 0.1688 - binary_accuracy: 0.9259 - balanced_acc: 0.9258 - f1: 0.9154 - f2: 0.8947 - recall: 0.8800 - specificity: 0.9693 - precision: 0.9593 - auc: 0.9823 - val_loss: 79.8238 - val_binary_accuracy: 0.5328 - val_balanced_acc: 0.5220 - val_f1: 0.4092 - val_f2: 0.3692 - val_recall: 0.3488 - val_specificity: 0.6967 - val_precision: 0.5048 - val_auc: 0.5301
# Epoch 10/50
# 100/100 [==============================] - 74s 743ms/step - loss: 0.1678 - binary_accuracy: 0.9256 - balanced_acc: 0.9269 - f1: 0.9162 - f2: 0.8964 - recall: 0.8799 - specificity: 0.9689 - precision: 0.9586 - auc: 0.9823 - val_loss: 70.5174 - val_binary_accuracy: 0.6000 - val_balanced_acc: 0.5994 - val_f1: 0.5632 - val_f2: 0.5576 - val_recall: 0.5533 - val_specificity: 0.6431 - val_precision: 0.5764 - val_auc: 0.6195
# Epoch 11/50
# 100/100 [==============================] - 74s 740ms/step - loss: 0.1473 - binary_accuracy: 0.9353 - balanced_acc: 0.9347 - f1: 0.9266 - f2: 0.9116 - recall: 0.9021 - specificity: 0.9668 - precision: 0.9582 - auc: 0.9861 - val_loss: 54.2241 - val_binary_accuracy: 0.6453 - val_balanced_acc: 0.6488 - val_f1: 0.6448 - val_f2: 0.6756 - val_recall: 0.7013 - val_specificity: 0.5989 - val_precision: 0.6023 - val_auc: 0.6553
# Epoch 12/50
# 100/100 [==============================] - 74s 741ms/step - loss: 0.1502 - binary_accuracy: 0.9319 - balanced_acc: 0.9315 - f1: 0.9213 - f2: 0.8966 - recall: 0.8787 - specificity: 0.9812 - precision: 0.9742 - auc: 0.9853 - val_loss: 41.0090 - val_binary_accuracy: 0.6453 - val_balanced_acc: 0.6484 - val_f1: 0.6551 - val_f2: 0.7001 - val_recall: 0.7416 - val_specificity: 0.5623 - val_precision: 0.5957 - val_auc: 0.6599
# Epoch 13/50
# 100/100 [==============================] - 74s 740ms/step - loss: 0.1371 - binary_accuracy: 0.9356 - balanced_acc: 0.9357 - f1: 0.9280 - f2: 0.9070 - recall: 0.8910 - specificity: 0.9770 - precision: 0.9703 - auc: 0.9877 - val_loss: 28.2515 - val_binary_accuracy: 0.6797 - val_balanced_acc: 0.6864 - val_f1: 0.6954 - val_f2: 0.7323 - val_recall: 0.7581 - val_specificity: 0.6111 - val_precision: 0.6438 - val_auc: 0.6882
# Epoch 14/50
# 100/100 [==============================] - 74s 745ms/step - loss: 0.1372 - binary_accuracy: 0.9369 - balanced_acc: 0.9367 - f1: 0.9282 - f2: 0.9076 - recall: 0.8925 - specificity: 0.9784 - precision: 0.9709 - auc: 0.9878 - val_loss: 15.9107 - val_binary_accuracy: 0.6828 - val_balanced_acc: 0.6871 - val_f1: 0.6994 - val_f2: 0.7459 - val_recall: 0.7803 - val_specificity: 0.5923 - val_precision: 0.6364 - val_auc: 0.6898
# Epoch 15/50
# 100/100 [==============================] - 74s 739ms/step - loss: 0.1393 - binary_accuracy: 0.9350 - balanced_acc: 0.9353 - f1: 0.9266 - f2: 0.9064 - recall: 0.8911 - specificity: 0.9762 - precision: 0.9681 - auc: 0.9876 - val_loss: 13.3785 - val_binary_accuracy: 0.6750 - val_balanced_acc: 0.6836 - val_f1: 0.6853 - val_f2: 0.7268 - val_recall: 0.7599 - val_specificity: 0.6070 - val_precision: 0.6311 - val_auc: 0.6895
# Epoch 16/50
# 100/100 [==============================] - 74s 743ms/step - loss: 0.1375 - binary_accuracy: 0.9391 - balanced_acc: 0.9395 - f1: 0.9318 - f2: 0.9103 - recall: 0.8933 - specificity: 0.9815 - precision: 0.9753 - auc: 0.9874 - val_loss: 8.7928 - val_binary_accuracy: 0.7016 - val_balanced_acc: 0.7040 - val_f1: 0.6947 - val_f2: 0.7371 - val_recall: 0.7751 - val_specificity: 0.6390 - val_precision: 0.6400 - val_auc: 0.7337
# Epoch 17/50
# 100/100 [==============================] - 74s 744ms/step - loss: 0.1355 - binary_accuracy: 0.9407 - balanced_acc: 0.9407 - f1: 0.9322 - f2: 0.9123 - recall: 0.8979 - specificity: 0.9810 - precision: 0.9739 - auc: 0.9882 - val_loss: 6.7751 - val_binary_accuracy: 0.7234 - val_balanced_acc: 0.7308 - val_f1: 0.7271 - val_f2: 0.7727 - val_recall: 0.8100 - val_specificity: 0.6517 - val_precision: 0.6694 - val_auc: 0.7684
# Epoch 18/50
# 100/100 [==============================] - 75s 751ms/step - loss: 0.1341 - binary_accuracy: 0.9391 - balanced_acc: 0.9396 - f1: 0.9321 - f2: 0.9160 - recall: 0.9037 - specificity: 0.9732 - precision: 0.9652 - auc: 0.9890 - val_loss: 5.0448 - val_binary_accuracy: 0.7406 - val_balanced_acc: 0.7438 - val_f1: 0.7522 - val_f2: 0.7963 - val_recall: 0.8301 - val_specificity: 0.6573 - val_precision: 0.6902 - val_auc: 0.7956
# Epoch 19/50
# 100/100 [==============================] - 74s 743ms/step - loss: 0.1326 - binary_accuracy: 0.9407 - balanced_acc: 0.9410 - f1: 0.9346 - f2: 0.9147 - recall: 0.8986 - specificity: 0.9793 - precision: 0.9733 - auc: 0.9889 - val_loss: 3.5215 - val_binary_accuracy: 0.7672 - val_balanced_acc: 0.7720 - val_f1: 0.7743 - val_f2: 0.8191 - val_recall: 0.8510 - val_specificity: 0.6909 - val_precision: 0.7119 - val_auc: 0.8237
# Epoch 20/50
# 100/100 [==============================] - 74s 742ms/step - loss: 0.1385 - binary_accuracy: 0.9341 - balanced_acc: 0.9356 - f1: 0.9268 - f2: 0.9070 - recall: 0.8891 - specificity: 0.9761 - precision: 0.9689 - auc: 0.9876 - val_loss: 2.5498 - val_binary_accuracy: 0.7859 - val_balanced_acc: 0.7886 - val_f1: 0.7886 - val_f2: 0.8264 - val_recall: 0.8576 - val_specificity: 0.7219 - val_precision: 0.7337 - val_auc: 0.8529
# Epoch 21/50
# 100/100 [==============================] - 74s 742ms/step - loss: 0.1238 - binary_accuracy: 0.9419 - balanced_acc: 0.9412 - f1: 0.9357 - f2: 0.9137 - recall: 0.8964 - specificity: 0.9823 - precision: 0.9781 - auc: 0.9898 - val_loss: 1.7846 - val_binary_accuracy: 0.8094 - val_balanced_acc: 0.8128 - val_f1: 0.8107 - val_f2: 0.8483 - val_recall: 0.8783 - val_specificity: 0.7491 - val_precision: 0.7585 - val_auc: 0.8819
# Epoch 22/50
# 100/100 [==============================] - 74s 737ms/step - loss: 0.1268 - binary_accuracy: 0.9422 - balanced_acc: 0.9414 - f1: 0.9341 - f2: 0.9134 - recall: 0.8997 - specificity: 0.9821 - precision: 0.9762 - auc: 0.9900 - val_loss: 1.2541 - val_binary_accuracy: 0.8313 - val_balanced_acc: 0.8346 - val_f1: 0.8301 - val_f2: 0.8658 - val_recall: 0.8926 - val_specificity: 0.7774 - val_precision: 0.7778 - val_auc: 0.9044
# Epoch 23/50
# 100/100 [==============================] - 75s 751ms/step - loss: 0.1299 - binary_accuracy: 0.9394 - balanced_acc: 0.9389 - f1: 0.9305 - f2: 0.9128 - recall: 0.9012 - specificity: 0.9757 - precision: 0.9677 - auc: 0.9894 - val_loss: 1.0512 - val_binary_accuracy: 0.8313 - val_balanced_acc: 0.8383 - val_f1: 0.8327 - val_f2: 0.8654 - val_recall: 0.8900 - val_specificity: 0.7852 - val_precision: 0.7807 - val_auc: 0.9129
# Epoch 24/50
# 100/100 [==============================] - 75s 746ms/step - loss: 0.1294 - binary_accuracy: 0.9403 - balanced_acc: 0.9421 - f1: 0.9344 - f2: 0.9176 - recall: 0.9022 - specificity: 0.9765 - precision: 0.9693 - auc: 0.9890 - val_loss: 0.7790 - val_binary_accuracy: 0.8500 - val_balanced_acc: 0.8539 - val_f1: 0.8514 - val_f2: 0.8790 - val_recall: 0.8958 - val_specificity: 0.8082 - val_precision: 0.8112 - val_auc: 0.9230
# Epoch 25/50
# 100/100 [==============================] - 75s 747ms/step - loss: 0.1298 - binary_accuracy: 0.9403 - balanced_acc: 0.9404 - f1: 0.9325 - f2: 0.9141 - recall: 0.8999 - specificity: 0.9778 - precision: 0.9712 - auc: 0.9889 - val_loss: 0.5352 - val_binary_accuracy: 0.8625 - val_balanced_acc: 0.8664 - val_f1: 0.8607 - val_f2: 0.8865 - val_recall: 0.9037 - val_specificity: 0.8271 - val_precision: 0.8218 - val_auc: 0.9404
# Epoch 26/50
# 100/100 [==============================] - 74s 742ms/step - loss: 0.1298 - binary_accuracy: 0.9413 - balanced_acc: 0.9419 - f1: 0.9342 - f2: 0.9167 - recall: 0.9027 - specificity: 0.9776 - precision: 0.9706 - auc: 0.9892 - val_loss: 0.4323 - val_binary_accuracy: 0.8641 - val_balanced_acc: 0.8674 - val_f1: 0.8576 - val_f2: 0.8784 - val_recall: 0.8915 - val_specificity: 0.8410 - val_precision: 0.8270 - val_auc: 0.9449
# Epoch 27/50
# 100/100 [==============================] - 75s 746ms/step - loss: 0.1332 - binary_accuracy: 0.9394 - balanced_acc: 0.9405 - f1: 0.9316 - f2: 0.9106 - recall: 0.8933 - specificity: 0.9827 - precision: 0.9759 - auc: 0.9881 - val_loss: 0.3661 - val_binary_accuracy: 0.8750 - val_balanced_acc: 0.8740 - val_f1: 0.8708 - val_f2: 0.8856 - val_recall: 0.8980 - val_specificity: 0.8518 - val_precision: 0.8478 - val_auc: 0.9526
# Epoch 28/50
# 100/100 [==============================] - 74s 742ms/step - loss: 0.1244 - binary_accuracy: 0.9419 - balanced_acc: 0.9409 - f1: 0.9333 - f2: 0.9129 - recall: 0.8987 - specificity: 0.9812 - precision: 0.9761 - auc: 0.9902 - val_loss: 0.3381 - val_binary_accuracy: 0.8781 - val_balanced_acc: 0.8786 - val_f1: 0.8662 - val_f2: 0.8811 - val_recall: 0.8926 - val_specificity: 0.8649 - val_precision: 0.8526 - val_auc: 0.9576
# Epoch 29/50
# 100/100 [==============================] - 74s 744ms/step - loss: 0.1270 - binary_accuracy: 0.9403 - balanced_acc: 0.9392 - f1: 0.9312 - f2: 0.9104 - recall: 0.8968 - specificity: 0.9807 - precision: 0.9747 - auc: 0.9897 - val_loss: 0.3260 - val_binary_accuracy: 0.8859 - val_balanced_acc: 0.8866 - val_f1: 0.8785 - val_f2: 0.8918 - val_recall: 0.9020 - val_specificity: 0.8716 - val_precision: 0.8585 - val_auc: 0.9591
# Epoch 30/50
# 100/100 [==============================] - 74s 736ms/step - loss: 0.1390 - binary_accuracy: 0.9331 - balanced_acc: 0.9348 - f1: 0.9253 - f2: 0.9090 - recall: 0.8950 - specificity: 0.9703 - precision: 0.9608 - auc: 0.9880 - val_loss: 0.2964 - val_binary_accuracy: 0.9016 - val_balanced_acc: 0.9019 - val_f1: 0.8946 - val_f2: 0.8992 - val_recall: 0.9033 - val_specificity: 0.9006 - val_precision: 0.8885 - val_auc: 0.9645
# Epoch 31/50
# 100/100 [==============================] - 73s 735ms/step - loss: 0.1317 - binary_accuracy: 0.9413 - balanced_acc: 0.9412 - f1: 0.9336 - f2: 0.9148 - recall: 0.8999 - specificity: 0.9788 - precision: 0.9733 - auc: 0.9889 - val_loss: 0.3065 - val_binary_accuracy: 0.8938 - val_balanced_acc: 0.8928 - val_f1: 0.8845 - val_f2: 0.8924 - val_recall: 0.9007 - val_specificity: 0.8874 - val_precision: 0.8774 - val_auc: 0.9640
# Epoch 32/50
# 100/100 [==============================] - 73s 731ms/step - loss: 0.1305 - binary_accuracy: 0.9429 - balanced_acc: 0.9435 - f1: 0.9368 - f2: 0.9189 - recall: 0.9031 - specificity: 0.9788 - precision: 0.9734 - auc: 0.9892 - val_loss: 0.2921 - val_binary_accuracy: 0.8984 - val_balanced_acc: 0.8987 - val_f1: 0.8929 - val_f2: 0.8940 - val_recall: 0.8944 - val_specificity: 0.9022 - val_precision: 0.8914 - val_auc: 0.9644
# Epoch 33/50
# 100/100 [==============================] - 73s 729ms/step - loss: 0.1350 - binary_accuracy: 0.9366 - balanced_acc: 0.9380 - f1: 0.9292 - f2: 0.9135 - recall: 0.9002 - specificity: 0.9719 - precision: 0.9630 - auc: 0.9879 - val_loss: 0.2737 - val_binary_accuracy: 0.8984 - val_balanced_acc: 0.8998 - val_f1: 0.8928 - val_f2: 0.8983 - val_recall: 0.9000 - val_specificity: 0.8971 - val_precision: 0.8852 - val_auc: 0.9655
# Epoch 34/50
# 100/100 [==============================] - 72s 723ms/step - loss: 0.1326 - binary_accuracy: 0.9400 - balanced_acc: 0.9402 - f1: 0.9317 - f2: 0.9137 - recall: 0.9007 - specificity: 0.9775 - precision: 0.9698 - auc: 0.9890 - val_loss: 0.2967 - val_binary_accuracy: 0.8969 - val_balanced_acc: 0.8981 - val_f1: 0.8888 - val_f2: 0.8904 - val_recall: 0.8900 - val_specificity: 0.9037 - val_precision: 0.8900 - val_auc: 0.9620
# Epoch 35/50
# 100/100 [==============================] - 72s 724ms/step - loss: 0.1338 - binary_accuracy: 0.9403 - balanced_acc: 0.9405 - f1: 0.9315 - f2: 0.9139 - recall: 0.9012 - specificity: 0.9776 - precision: 0.9698 - auc: 0.9886 - val_loss: 0.2866 - val_binary_accuracy: 0.9000 - val_balanced_acc: 0.8984 - val_f1: 0.8887 - val_f2: 0.8924 - val_recall: 0.9000 - val_specificity: 0.9011 - val_precision: 0.8882 - val_auc: 0.9642
# Epoch 36/50
# 100/100 [==============================] - 72s 724ms/step - loss: 0.1366 - binary_accuracy: 0.9334 - balanced_acc: 0.9341 - f1: 0.9247 - f2: 0.9053 - recall: 0.8909 - specificity: 0.9744 - precision: 0.9654 - auc: 0.9877 - val_loss: 0.2815 - val_binary_accuracy: 0.9031 - val_balanced_acc: 0.9062 - val_f1: 0.8962 - val_f2: 0.8955 - val_recall: 0.8925 - val_specificity: 0.9161 - val_precision: 0.9043 - val_auc: 0.9655
# Epoch 37/50
# 100/100 [==============================] - 73s 728ms/step - loss: 0.1298 - binary_accuracy: 0.9375 - balanced_acc: 0.9374 - f1: 0.9270 - f2: 0.9102 - recall: 0.8985 - specificity: 0.9740 - precision: 0.9663 - auc: 0.9894 - val_loss: 0.2982 - val_binary_accuracy: 0.8922 - val_balanced_acc: 0.8897 - val_f1: 0.8824 - val_f2: 0.8815 - val_recall: 0.8849 - val_specificity: 0.8982 - val_precision: 0.8878 - val_auc: 0.9606
# Epoch 38/50
# 100/100 [==============================] - 73s 728ms/step - loss: 0.1293 - binary_accuracy: 0.9400 - balanced_acc: 0.9400 - f1: 0.9317 - f2: 0.9142 - recall: 0.9012 - specificity: 0.9763 - precision: 0.9691 - auc: 0.9897 - val_loss: 0.2804 - val_binary_accuracy: 0.8969 - val_balanced_acc: 0.8965 - val_f1: 0.8901 - val_f2: 0.8868 - val_recall: 0.8845 - val_specificity: 0.9080 - val_precision: 0.8963 - val_auc: 0.9640
# Epoch 39/50
# 100/100 [==============================] - 73s 733ms/step - loss: 0.1338 - binary_accuracy: 0.9419 - balanced_acc: 0.9431 - f1: 0.9345 - f2: 0.9163 - recall: 0.9012 - specificity: 0.9807 - precision: 0.9735 - auc: 0.9886 - val_loss: 0.2930 - val_binary_accuracy: 0.8984 - val_balanced_acc: 0.8996 - val_f1: 0.8886 - val_f2: 0.8827 - val_recall: 0.8771 - val_specificity: 0.9197 - val_precision: 0.9041 - val_auc: 0.9618
# Epoch 40/50
# 100/100 [==============================] - 73s 728ms/step - loss: 0.1352 - binary_accuracy: 0.9410 - balanced_acc: 0.9423 - f1: 0.9346 - f2: 0.9183 - recall: 0.9039 - specificity: 0.9759 - precision: 0.9685 - auc: 0.9881 - val_loss: 0.2839 - val_binary_accuracy: 0.9062 - val_balanced_acc: 0.9031 - val_f1: 0.8990 - val_f2: 0.8926 - val_recall: 0.8914 - val_specificity: 0.9172 - val_precision: 0.9094 - val_auc: 0.9644
# Epoch 41/50
# 100/100 [==============================] - 73s 734ms/step - loss: 0.1209 - binary_accuracy: 0.9425 - balanced_acc: 0.9429 - f1: 0.9352 - f2: 0.9175 - recall: 0.9032 - specificity: 0.9788 - precision: 0.9727 - auc: 0.9908 - val_loss: 0.2797 - val_binary_accuracy: 0.9047 - val_balanced_acc: 0.9020 - val_f1: 0.8964 - val_f2: 0.8862 - val_recall: 0.8800 - val_specificity: 0.9243 - val_precision: 0.9135 - val_auc: 0.9645
# Epoch 42/50
# 100/100 [==============================] - 74s 735ms/step - loss: 0.1291 - binary_accuracy: 0.9394 - balanced_acc: 0.9406 - f1: 0.9325 - f2: 0.9171 - recall: 0.9040 - specificity: 0.9733 - precision: 0.9651 - auc: 0.9894 - val_loss: 0.2916 - val_binary_accuracy: 0.9031 - val_balanced_acc: 0.9017 - val_f1: 0.8951 - val_f2: 0.8846 - val_recall: 0.8783 - val_specificity: 0.9252 - val_precision: 0.9144 - val_auc: 0.9622
# Epoch 43/50
# 100/100 [==============================] - 74s 737ms/step - loss: 0.1404 - binary_accuracy: 0.9359 - balanced_acc: 0.9372 - f1: 0.9271 - f2: 0.9105 - recall: 0.8973 - specificity: 0.9736 - precision: 0.9642 - auc: 0.9881 - val_loss: 0.2855 - val_binary_accuracy: 0.9031 - val_balanced_acc: 0.9025 - val_f1: 0.8930 - val_f2: 0.8815 - val_recall: 0.8738 - val_specificity: 0.9308 - val_precision: 0.9164 - val_auc: 0.9640
# Epoch 44/50
# 100/100 [==============================] - 73s 731ms/step - loss: 0.1306 - binary_accuracy: 0.9419 - balanced_acc: 0.9409 - f1: 0.9341 - f2: 0.9151 - recall: 0.9032 - specificity: 0.9782 - precision: 0.9722 - auc: 0.9887 - val_loss: 0.2877 - val_binary_accuracy: 0.9016 - val_balanced_acc: 0.8997 - val_f1: 0.8909 - val_f2: 0.8797 - val_recall: 0.8721 - val_specificity: 0.9267 - val_precision: 0.9120 - val_auc: 0.9642
# Epoch 45/50
# 100/100 [==============================] - 73s 733ms/step - loss: 0.1335 - binary_accuracy: 0.9410 - balanced_acc: 0.9416 - f1: 0.9345 - f2: 0.9168 - recall: 0.9022 - specificity: 0.9771 - precision: 0.9707 - auc: 0.9889 - val_loss: 0.2724 - val_binary_accuracy: 0.9109 - val_balanced_acc: 0.9091 - val_f1: 0.9021 - val_f2: 0.8834 - val_recall: 0.8696 - val_specificity: 0.9466 - val_precision: 0.9353 - val_auc: 0.9668
# Epoch 46/50
# 100/100 [==============================] - 73s 730ms/step - loss: 0.1353 - binary_accuracy: 0.9407 - balanced_acc: 0.9407 - f1: 0.9326 - f2: 0.9120 - recall: 0.8965 - specificity: 0.9819 - precision: 0.9753 - auc: 0.9881 - val_loss: 0.2799 - val_binary_accuracy: 0.9000 - val_balanced_acc: 0.8986 - val_f1: 0.8909 - val_f2: 0.8749 - val_recall: 0.8642 - val_specificity: 0.9322 - val_precision: 0.9190 - val_auc: 0.9646
# Epoch 47/50
# 100/100 [==============================] - 73s 728ms/step - loss: 0.1370 - binary_accuracy: 0.9363 - balanced_acc: 0.9372 - f1: 0.9274 - f2: 0.9097 - recall: 0.8955 - specificity: 0.9751 - precision: 0.9669 - auc: 0.9876 - val_loss: 0.2740 - val_binary_accuracy: 0.9047 - val_balanced_acc: 0.9008 - val_f1: 0.8926 - val_f2: 0.8772 - val_recall: 0.8682 - val_specificity: 0.9337 - val_precision: 0.9211 - val_auc: 0.9670
# Epoch 48/50
# 100/100 [==============================] - 73s 733ms/step - loss: 0.1321 - binary_accuracy: 0.9385 - balanced_acc: 0.9388 - f1: 0.9309 - f2: 0.9128 - recall: 0.8979 - specificity: 0.9756 - precision: 0.9690 - auc: 0.9888 - val_loss: 0.2790 - val_binary_accuracy: 0.9000 - val_balanced_acc: 0.8956 - val_f1: 0.8851 - val_f2: 0.8682 - val_recall: 0.8624 - val_specificity: 0.9332 - val_precision: 0.9179 - val_auc: 0.9657
# Epoch 49/50
# 100/100 [==============================] - 73s 731ms/step - loss: 0.1284 - binary_accuracy: 0.9419 - balanced_acc: 0.9425 - f1: 0.9341 - f2: 0.9167 - recall: 0.9021 - specificity: 0.9784 - precision: 0.9727 - auc: 0.9895 - val_loss: 0.2903 - val_binary_accuracy: 0.9000 - val_balanced_acc: 0.8958 - val_f1: 0.8871 - val_f2: 0.8690 - val_recall: 0.8605 - val_specificity: 0.9339 - val_precision: 0.9217 - val_auc: 0.9643
# Epoch 50/50
# 100/100 [==============================] - 73s 729ms/step - loss: 0.1316 - binary_accuracy: 0.9378 - balanced_acc: 0.9389 - f1: 0.9301 - f2: 0.9150 - recall: 0.9024 - specificity: 0.9719 - precision: 0.9629 - auc: 0.9889 - val_loss: 0.2814 - val_binary_accuracy: 0.9016 - val_balanced_acc: 0.9016 - val_f1: 0.8924 - val_f2: 0.8784 - val_recall: 0.8667 - val_specificity: 0.9331 - val_precision: 0.9187 - val_auc: 0.9676
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: saved_models/nnmobile/assets

# %% [markdown]
# **Training and Validation Metrics**

# %%
graph_metrics(history)

# %% [markdown]
# **Make Predictions**

# %%
# test_generator = test2_generator
test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(
        TEST_DIR,
        target_size=IMAGE_SIZE,
        shuffle=False,
        class_mode='binary'
    )
y_true = 1 - test_generator.classes
prediction = (1 - model.predict(test_generator))
y_pred = [1 * (x[0]>=.35) for x in prediction]
# Out:
# Found 690 images belonging to 2 classes.

# %% [markdown]
# **Visualize Predictions**

# %%
index = 0
while index < len(prediction):
  probability = prediction[index]
  image_path =  TEST_DIR + "/" +test_generator.filenames[index]
  image = mpimg.imread(image_path, 0)
  #BGR TO RGB conversion using CV2
  image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
  pixels = np.array(image)
  plt.imshow(pixels)
  print("prob:{}".format(probability))
  print(test_generator.filenames[index])
    
  plt.title('%.2f' % ((probability)*100) + '% COVID')
  plt.show()
  index+=random.randint(50,150)
# Out:
# prob:[0.8552494]
# COVID/2019-novel-Coronavirus-severe-adult-respiratory-dist_2020_International-Jour-p3-89%1.png
# prob:[0.999948]
# COVID/Covid (115).png
# prob:[0.8542234]
# COVID/Covid (860).png
# prob:[0.9998309]
# COVID/img401.jpg
# prob:[0.99920607]
# NonCOVID/25%3.jpg
# prob:[0.000157]
# NonCOVID/Non-Covid (1092).png
# prob:[7.5101852e-06]
# NonCOVID/Non-Covid (369).png
# prob:[1.8954277e-05]
# NonCOVID/Non-Covid (843).png
# prob:[0.]
# NonCOVID/nor_15_img_2.jpg

# %% [markdown]
# **Evaluate Model**

# %%
print(metrics.classification_report(y_true, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.85      0.88       325
#            1       0.88      0.93      0.90       365
#
#     accuracy                           0.90       690
#    macro avg       0.90      0.89      0.89       690
# weighted avg       0.90      0.90      0.90       690

# %% [markdown]
# **In-Depth Metrics Report**
# see https://en.wikipedia.org/wiki/Confusion_matrix

# %%
def matrix_metrix(y_true, y_pred):
    CM = metrics.confusion_matrix(y_true , y_pred)
    TN = CM[0][0]
    FN = CM[1][0] 
    TP = CM[1][1]
    FP = CM[0][1]
    Population = TN+FN+TP+FP
    Prevalence = round( (TP+FP) / Population,3)
    Accuracy   = round( (TP+TN) / Population,3)
    Precision  = round( TP / (TP+FP),3 )
    NPV        = round( TN / (TN+FN),3 )
    FDR        = round( FP / (TP+FP),3 )
    FOR        = round( FN / (TN+FN),3 ) 
    check_Pos  = Precision + FDR
    check_Neg  = NPV + FOR
    Recall     = round( TP / (TP+FN),3 )
    FPR        = round( FP / (TN+FP),3 )
    Specificity = 1 - FPR
    FNR        = round( FN / (TP+FN),3)
    TNR        = round( TN / (TN+FP),3 ) 
    check_Pos2 = Recall + FNR
    check_Neg2 = FPR + TNR
    LRPos      = round( Recall/FPR,3 ) 
    LRNeg      = round( FNR / TNR ,3 )
    DOR        = round( LRPos/LRNeg)
    F1         = round ( 2 * ((Precision*Recall)/(Precision+Recall)),4)
    F2      = round ( (1+2**2)*((Precision*Recall)/((2**2 * Precision)+ Recall)) ,4)
    MCC        = round ( ((TP*TN)-(FP*FN))/math.sqrt((TP+FP)*(TP+FN)*(TN+FP)*(TN+FN))  ,4)
    BM         = Recall+TNR-1
    MK         = Precision+NPV-1
    AUC = round(roc_auc_score(y_true, y_pred),3)

    met_dict = {
   'TP': TP,'TN':TN,'FP':FP,  'FN':FN,   'Prevalence':Prevalence, 
     'Accuracy':Accuracy,   'Precision':Precision,'Recall':Recall,
    'F1':F1,  'F2':F2, 'AUC':AUC, 'NPV':NPV,'FPR':FPR,
   'TNR':Specificity,  'FNR':FNR, 'TNR':TNR,'FDR':FDR,'FOR':FOR,'check_Pos':check_Pos,
   'check_Neg':check_Neg,  'check_Pos2':check_Pos2, 'check_Neg2':check_Neg2, 'LR+':LRPos,
    'LR-':LRNeg,  'DOR':DOR, 'MCC':MCC,'BM':BM,'MK':MK 
   }  

    return met_dict

for key, value in matrix_metrix(y_true, y_pred).items(): 
    print("{:<10} {:<10}".format(key, value))
# Out:
# TP         341
# TN         277
# FP         48
# FN         24
# Prevalence 0.564
# Accuracy   0.896
# Precision  0.877
# Recall     0.934
# F1         0.9046
# F2         0.922
# AUC        0.893
# NPV        0.92
# FPR        0.148
# TNR        0.852
# FNR        0.066
# FDR        0.123
# FOR        0.08
# check_Pos  1.0
# check_Neg  1.0
# check_Pos2 1.0
# check_Neg2 1.0
# LR+        6.311
# LR-        0.077
# DOR        82.0
# MCC        0.7917
# BM         0.786
# MK         0.7970000000000002

# %% [markdown]
# **Confusion Matrix**

# %%
def plot_confusion_matrix(cm, classes,
    normalize=False,
    title='Confusion matrix',
    cmap=plt.cm.Blues):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')
    
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt), fontsize= 20,
                 horizontalalignment="center",
                 color="yellow" if cm[i, j] > thresh else "red")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()
cm=metrics.confusion_matrix(y_true,y_pred)
plot_confusion_matrix(cm=cm, classes=['NON-COVID', 'COVID'], title='Confusion Matrix')
plot_confusion_matrix(cm=cm, classes=['NON-COVID', 'COVID'], title='Confusion Matrix', normalize=True)
# Out:
# Confusion matrix, without normalization
# Normalized confusion matrix

# %% [markdown]
# **ROC Curve**

# %%
#ROC Implementation
def get_roc_curve(y_true, y_pred):
  print("AUC: " + str(metrics.roc_auc_score(y_true, y_pred)))
  fpr, tpr, thresholds = roc_curve(y_true, y_pred)
  # print(fpr)
  # print(tpr)
  pyplot.plot(fpr, tpr, linestyle='--', label='ROC curve')
  pyplot.xlabel('False Positive Rate')
  pyplot.ylabel('True Positive Rate')
  pyplot.legend()
  pyplot.show()
  
get_roc_curve(y_true, prediction)
# Out:
# AUC: 0.9643414120126449

# %% [markdown]
# **Precision-Recall Curve**

# %%
def get_pr_curve(y_true, y_pred):
  print("Average Precision: " +  str(sklearn.metrics.average_precision_score(y_true, y_pred)))
  precision, recall, thresholds = sklearn.metrics.precision_recall_curve(y_true, y_pred)
  pyplot.plot(recall, precision, linestyle='--', label='Precision versus Recall')
  pyplot.xlabel('Recall')
  pyplot.ylabel('Precision')
  pyplot.legend()
  pyplot.show()

get_pr_curve(y_true, prediction)
# Out:
# Average Precision: 0.963712665796717

# %% [markdown]
# **Compare Metrics at Different Classification Thresholds**

# %%
thresholds = [round(i * .01, 2) for i in range(1,100)]
def metric_against_thresholds(metric):
    vals = []
    for t in thresholds:
      y_pred = [1 * (x>=t) for x in prediction]
    
      vals.append(float(matrix_metrix(y_true, y_pred)[metric]))

    return vals

def plot_metrics_against_thresholds(desired_metrics= ["Accuracy","Precision", "Recall", "F1", "F2"]):
  pyplot.figure(figsize=(14,14))
  pyplot.xlabel("Classification Threshold", fontsize=15)
  pyplot.ylabel("Metric Value", fontsize=15)
  for i in range(len(desired_metrics)):
    pyplot.plot(thresholds, metric_against_thresholds(desired_metrics[i]), lw=2, label=desired_metrics[i])
  pyplot.legend(title="Metrics", fontsize='large')
  pyplot.grid()
  pyplot.show()
plot_metrics_against_thresholds()

# %% [markdown]
# **Optimal Cutoffs**
#
# see https://www.hindawi.com/journals/cmmm/2017/3762651/

# %%
def get_optimal_cutoffs():
  TN, FP, FN, TP = metrics.confusion_matrix(y_true,y_pred).ravel()
  sensitivity = round( TP / (TP+FN),2 )
  specificity = round( TN / (TN+FP),2 )
  auc = metrics.roc_auc_score(y_true, y_pred)

  youden = sensitivity + specificity - 1
  print("youden: " + str(youden))

  closest_to_01 =  np.sqrt(((1 - sensitivity)**2) + ((1 - specificity)**2))
  print("Closest to (0,1): " + str(np.around(closest_to_01, decimals = 3)))

  concordance_probability = sensitivity * specificity
  print("Concordance Probability: " + str((np.around(concordance_probability, decimals = 3))))

  index_of_union = np.abs(sensitivity - auc) + np.abs(specificity - auc)
  print("Index of Union: " + str((np.around(index_of_union, decimals = 3))))

get_optimal_cutoffs()
# Out:
# youden: 0.78
# Closest to (0,1): 0.166
# Concordance Probability: 0.79
# Index of Union: 0.08
