# %% [markdown]
# # Contents
#
#       Training
#            - Imports
#            - Mounting Drive
#            - Getting paths and directories, setting global variables
#            - Pre-processing and Data Augmentation
#            - Previewing Data Augmentation
#            - Functions to calculate metrics
#            - Model build using transfer learning architecture.
#            - Function to graph model metrics
#            - Train and Save Model
#            - Training and Validation Metrics
#       Testing
#           - Make Predictions
#           - Visualize Predictions
#           - Evaluate Model
#           - In-Depth Metrics Report
#           - Confusion Matrix
#           - ROC Curve
#           - Precision-Recall Curve
#           - Compare Metrics at Different Classification Thresholds
#           - Optimal Cutoffs

# %% [markdown]
# **Imports**

# %%
import os, shutil, PIL, keras
import matplotlib.pyplot as plt
import tensorflow as tf
import keras.backend as K
import random
import numpy as np
import cv2

from pathlib import Path
from keras import layers, models, optimizers, regularizers

from keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing import image
from keras.applications.densenet import DenseNet121
from keras.applications.nasnet import NASNetMobile
from keras.applications import InceptionResNetV2
from keras.models import Model, Input, Sequential,load_model
from keras.layers import AveragePooling2D, Dense, Dropout, Conv2D, MaxPool2D, Flatten
from keras.callbacks import Callback, ModelCheckpoint
from keras.wrappers.scikit_learn import KerasClassifier


from sklearn import metrics

import matplotlib.image as mpimg

import itertools
from sklearn import metrics

import sklearn.metrics
import math
import pandas as pd


from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from matplotlib import pyplot

# %% [markdown]
# **Mounting Drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !pip install pyyaml h5py  # Required to save models in HDF5 format
# Out:
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (3.13)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (2.10.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from h5py) (1.15.0)
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.6/dist-packages (from h5py) (1.18.5)

# %% [markdown]
# **Getting paths and directories, setting global variables**

# %%
IMAGE_SIZE = (224, 224)
TRAIN_BATCH_SIZE = 32
VAL_BATCH_SIZE = 64
NUM_EPOCHS = 35
TRANSFER_MODEL = tf.keras.applications.Xception(input_shape=(IMAGE_SIZE[0],IMAGE_SIZE[1],3), include_top=False)
#percent of layers that will be trainable from original model
PERCENT_TRAINABLE = 0.5


TRAIN_DIR = '/content/drive/My Drive/CVT/data/train'
VAL_DIR = '/content/drive/My Drive/CVT/data/validation'
TEST_DIR = '/content/drive/My Drive/CVT/data/test'
#hold-out set
TEST2_DIR = '/content/drive/My Drive/CVT/HO-data'

NUM_TRAIN_SAMPLES = len(os.listdir(TRAIN_DIR + "/COVID")) + len(os.listdir(TRAIN_DIR + "/NonCOVID"))
NUM_VAL_SAMPLES = len(os.listdir(VAL_DIR + "/COVID")) + len(os.listdir(VAL_DIR + "/NonCOVID"))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83689472/83683744 [==============================] - 1s 0us/step

# %% [markdown]
# **Pre-processing and Data Augmentation**

# %%
def preprocess_data():
    train_datagen = ImageDataGenerator(
        rescale=1./255,
        rotation_range=10,
        width_shift_range=0.05,
        height_shift_range=0.05,
        brightness_range=[0.5, 1.0],
        shear_range=0.05,
        zoom_range=0.15,
        horizontal_flip=True,
        # vertical_flip=True,
        # fill_mode="constant",
        # cval=255
    )

    test_datagen = ImageDataGenerator(rescale=1./255)

    test_generator = test_datagen.flow_from_directory(
        TEST_DIR,
        target_size=IMAGE_SIZE,
        shuffle=False,
        class_mode='binary'
    )

    train_generator = train_datagen.flow_from_directory(
          TRAIN_DIR,
          target_size=IMAGE_SIZE,
          batch_size=TRAIN_BATCH_SIZE,
          class_mode='binary'
       )

    validation_generator = test_datagen.flow_from_directory(
        VAL_DIR,
        target_size=IMAGE_SIZE,
        batch_size=VAL_BATCH_SIZE,
        class_mode='binary'
    )
    
    test_generator2 = test_datagen.flow_from_directory(
        TEST2_DIR,
        target_size=IMAGE_SIZE,
        shuffle=False,
        class_mode='binary'
    )

    return (train_generator, validation_generator, test_generator, test_generator2)

def add_noise_contrast(img):
    VARIABILITY = 25
    deviation = VARIABILITY*random.random()
    noise = np.random.normal(0, deviation, img.shape)
    img += noise
    np.clip(img, 0., 255.)
    return img

def augment(img):
    if np.random.random() < 0.3:
      kernel = np.ones((5, 5), np.uint8)
      img = cv2.erode(img, kernel, iterations=1)
    if np.random.random() < 0.3:
      kernel = np.ones((5, 5), np.uint8)
      img = cv2.dilate(img, kernel, iterations=1) 
    # return add_noise_contrast(img)
    return img

# %% [markdown]
# **Previewing Data Augmentation**

# %%
def test_augmentation():
    datagen = ImageDataGenerator(
        rescale=1./255,
        rotation_range=10,
        width_shift_range=0.04,
        height_shift_range=0.04,
        brightness_range=[0.4, 1.0],
        shear_range=0.05,
        zoom_range=0.2,
        horizontal_flip=True,
        # vertical_flip=True,
        # fill_mode="constant",
        # cval=255

    )
  
    fnames_covid = [os.path.join(TRAIN_DIR, 'COVID', fname) for fname in os.listdir(os.path.join(TRAIN_DIR, 'COVID'))]
    fnames_noncovid = [os.path.join(TRAIN_DIR, 'NonCOVID', fname) for fname in os.listdir(os.path.join(TRAIN_DIR, 'NonCOVID'))]
    fnames = fnames_covid + fnames_noncovid
    for r in range(3):
      img_path = fnames[random.randint(0, len(fnames) - 1)]
      print(img_path)

      img = image.load_img(img_path, target_size=IMAGE_SIZE)
      x = image.img_to_array(img)
      x = x.reshape((1,) + x.shape)
      print(x.shape)
      i = 0
      for batch in datagen.flow(x, batch_size=1):
          plt.figure(i)
          imgplot = plt.imshow(image.array_to_img(batch[0]))
          i += 1
          if (i % 3 == 0):
            break
      plt.show()

test_augmentation()
# Out:
# /content/drive/My Drive/CVT/data/train/COVID/img534.jpg
# (1, 224, 224, 3)
# /content/drive/My Drive/CVT/data/train/COVID/img506.jpg
# (1, 224, 224, 3)
# /content/drive/My Drive/CVT/data/train/NonCOVID/img221.jpg
# (1, 224, 224, 3)

# %% [markdown]
# **Functions to calculate metrics**

# %%
def f1(y_true, y_pred): 
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

def f2(y_true, y_pred): 
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f2_val = (5 * precision * recall) / (4 * precision + recall+K.epsilon())
    return f2_val


def sensitivity(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    return true_positives / (possible_positives + K.epsilon())

def specificity(y_true, y_pred):
    true_negatives = K.sum(K.round(K.clip((1-y_true) * (1-y_pred), 0, 1)))
    possible_negatives = K.sum(K.round(K.clip(1-y_true, 0, 1)))
    return true_negatives / (possible_negatives + K.epsilon())

def balanced_acc(y_true, y_pred):
    return (sensitivity(y_true, y_pred) + specificity(y_true, y_pred))/2

# %% [markdown]
# **Model build using transfer learning architecture.**

# %%
def build_transfer():
  IMG_SHAPE = (224, 224, 3)

  for index,layer in enumerate(TRANSFER_MODEL.layers):
    if index < len(TRANSFER_MODEL.layers) * PERCENT_TRAINABLE: 
      layer.trainable = False 
    else:
      layer.trainable = True 
      

  X = layers.Flatten()(TRANSFER_MODEL.output)    
  X = layers.Dense(64)(X)
  X = layers.Activation('relu')(X)
  X = layers.Dropout(0.5)(X)                   
  X = layers.Dense (1, activation='sigmoid')(X)           

  model = Model(TRANSFER_MODEL.input, X) 

  model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=[
                       tf.keras.metrics.BinaryAccuracy(threshold=0.5),
                       balanced_acc, 
                       f1, 
                       f2,
                       tf.keras.metrics.Recall(name="recall"), 
                       specificity,
                       tf.keras.metrics.Precision(name='precision'),
                       tf.keras.metrics.AUC(name="auc")])
  return model

# %% [markdown]
# **Function to graph model metrics**

# %%
def graph_metrics(history):
  metrics_list = list(history.history.keys())
  num_metrics = int(len(metrics_list)/2)

  fig, axs = plt.subplots(math.ceil(num_metrics/2), 2, figsize=(20, 35))

  epochs = range(1, NUM_EPOCHS+1)

  for i in range(num_metrics):
    train_metric = history.history[metrics_list[i]]
    val_metric = history.history[metrics_list[i + num_metrics]]
    row = int(i/2)
    col = 1 * (i % 2 != 0)
    axs[row, col].plot(epochs, train_metric, label='Training ' + metrics_list[i])
    axs[row, col].plot(epochs, val_metric, label='Validation ' + metrics_list[i])
    axs[row, col].set_title(metrics_list[i])
    axs[row, col].legend()

  plt.delaxes(axs[math.ceil(num_metrics/2)-1, 1])
  plt.show()

# %% [markdown]
# **Train and Save Model**

# %%
def train(model, train_generator, validation_generator):
    history = model.fit(
                    train_generator,
                    steps_per_epoch=NUM_TRAIN_SAMPLES//TRAIN_BATCH_SIZE,
                    epochs=NUM_EPOCHS,
                    validation_data=validation_generator,
                    validation_steps=NUM_VAL_SAMPLES//VAL_BATCH_SIZE,
                    callbacks = [tf.keras.callbacks.ReduceLROnPlateau(patience=5)]
            )
    return history

# %%
model = build_transfer()
train_generator, validation_generator, test_generator, test2_generator = preprocess_data()
history = train(model, train_generator, validation_generator)
# Out:
# Found 690 images belonging to 2 classes.
# Found 3217 images belonging to 2 classes.
# Found 690 images belonging to 2 classes.
# Found 361 images belonging to 2 classes.
# Epoch 1/35
# 100/100 [==============================] - 878s 9s/step - loss: 0.6885 - binary_accuracy: 0.6854 - balanced_acc: 0.6750 - f1: 0.5592 - f2: 0.5297 - recall: 0.5206 - specificity: 0.8323 - precision: 0.7350 - auc: 0.7452 - val_loss: 0.8258 - val_binary_accuracy: 0.6891 - val_balanced_acc: 0.6978 - val_f1: 0.7152 - val_f2: 0.7889 - val_recall: 0.8451 - val_specificity: 0.5469 - val_precision: 0.6213 - val_auc: 0.8142
# Epoch 2/35
# 100/100 [==============================] - 91s 914ms/step - loss: 0.4352 - binary_accuracy: 0.8173 - balanced_acc: 0.8188 - f1: 0.7942 - f2: 0.7768 - recall: 0.7647 - specificity: 0.8680 - precision: 0.8336 - auc: 0.8820 - val_loss: 0.6306 - val_binary_accuracy: 0.8109 - val_balanced_acc: 0.8090 - val_f1: 0.7928 - val_f2: 0.7827 - val_recall: 0.7796 - val_specificity: 0.8412 - val_precision: 0.8144 - val_auc: 0.8925
# Epoch 3/35
# 100/100 [==============================] - 93s 934ms/step - loss: 0.3648 - binary_accuracy: 0.8484 - balanced_acc: 0.8500 - f1: 0.8281 - f2: 0.8043 - recall: 0.7858 - specificity: 0.9084 - precision: 0.8800 - auc: 0.9192 - val_loss: 0.9618 - val_binary_accuracy: 0.8094 - val_balanced_acc: 0.8133 - val_f1: 0.8050 - val_f2: 0.8315 - val_recall: 0.8510 - val_specificity: 0.7752 - val_precision: 0.7695 - val_auc: 0.8868
# Epoch 4/35
# 100/100 [==============================] - 96s 958ms/step - loss: 0.3104 - binary_accuracy: 0.8725 - balanced_acc: 0.8743 - f1: 0.8558 - f2: 0.8320 - recall: 0.8130 - specificity: 0.9300 - precision: 0.9072 - auc: 0.9427 - val_loss: 1.6331 - val_binary_accuracy: 0.7984 - val_balanced_acc: 0.7870 - val_f1: 0.7306 - val_f2: 0.6381 - val_recall: 0.5908 - val_specificity: 0.9849 - val_precision: 0.9728 - val_auc: 0.8658
# Epoch 5/35
# 100/100 [==============================] - 92s 917ms/step - loss: 0.2828 - binary_accuracy: 0.8835 - balanced_acc: 0.8849 - f1: 0.8655 - f2: 0.8357 - recall: 0.8124 - specificity: 0.9507 - precision: 0.9321 - auc: 0.9518 - val_loss: 0.4667 - val_binary_accuracy: 0.8313 - val_balanced_acc: 0.8323 - val_f1: 0.8276 - val_f2: 0.8448 - val_recall: 0.8567 - val_specificity: 0.8074 - val_precision: 0.8043 - val_auc: 0.9307
# Epoch 6/35
# 100/100 [==============================] - 93s 928ms/step - loss: 0.2505 - binary_accuracy: 0.8917 - balanced_acc: 0.8911 - f1: 0.8727 - f2: 0.8379 - recall: 0.8129 - specificity: 0.9644 - precision: 0.9502 - auc: 0.9620 - val_loss: 0.9381 - val_binary_accuracy: 0.8125 - val_balanced_acc: 0.8126 - val_f1: 0.8110 - val_f2: 0.8211 - val_recall: 0.8285 - val_specificity: 0.7961 - val_precision: 0.7926 - val_auc: 0.9038
# Epoch 7/35
# 100/100 [==============================] - 92s 924ms/step - loss: 0.2758 - binary_accuracy: 0.8860 - balanced_acc: 0.8845 - f1: 0.8681 - f2: 0.8437 - recall: 0.8296 - specificity: 0.9386 - precision: 0.9209 - auc: 0.9556 - val_loss: 2.1280 - val_binary_accuracy: 0.7719 - val_balanced_acc: 0.7771 - val_f1: 0.7752 - val_f2: 0.8124 - val_recall: 0.8339 - val_specificity: 0.7135 - val_precision: 0.7233 - val_auc: 0.8510
# Epoch 8/35
# 100/100 [==============================] - 93s 927ms/step - loss: 0.2859 - binary_accuracy: 0.8876 - balanced_acc: 0.8892 - f1: 0.8731 - f2: 0.8496 - recall: 0.8303 - specificity: 0.9420 - precision: 0.9228 - auc: 0.9547 - val_loss: 0.4131 - val_binary_accuracy: 0.8844 - val_balanced_acc: 0.8788 - val_f1: 0.8604 - val_f2: 0.8184 - val_recall: 0.7946 - val_specificity: 0.9642 - val_precision: 0.9478 - val_auc: 0.9337
# Epoch 9/35
# 100/100 [==============================] - 93s 932ms/step - loss: 0.2706 - binary_accuracy: 0.8860 - balanced_acc: 0.8893 - f1: 0.8693 - f2: 0.8409 - recall: 0.8148 - specificity: 0.9525 - precision: 0.9341 - auc: 0.9567 - val_loss: 2.3588 - val_binary_accuracy: 0.8328 - val_balanced_acc: 0.8372 - val_f1: 0.8374 - val_f2: 0.8805 - val_recall: 0.9112 - val_specificity: 0.7617 - val_precision: 0.7759 - val_auc: 0.8991
# Epoch 10/35
# 100/100 [==============================] - 93s 927ms/step - loss: 0.3203 - binary_accuracy: 0.8732 - balanced_acc: 0.8767 - f1: 0.8556 - f2: 0.8336 - recall: 0.8140 - specificity: 0.9312 - precision: 0.9081 - auc: 0.9464 - val_loss: 4.3896 - val_binary_accuracy: 0.7953 - val_balanced_acc: 0.7835 - val_f1: 0.7223 - val_f2: 0.6309 - val_recall: 0.5833 - val_specificity: 0.9846 - val_precision: 0.9669 - val_auc: 0.8194
# Epoch 11/35
# 100/100 [==============================] - 94s 940ms/step - loss: 0.2954 - binary_accuracy: 0.8791 - balanced_acc: 0.8805 - f1: 0.8620 - f2: 0.8369 - recall: 0.8140 - specificity: 0.9383 - precision: 0.9201 - auc: 0.9515 - val_loss: 0.4934 - val_binary_accuracy: 0.8562 - val_balanced_acc: 0.8484 - val_f1: 0.8263 - val_f2: 0.7681 - val_recall: 0.7333 - val_specificity: 0.9627 - val_precision: 0.9483 - val_auc: 0.9279
# Epoch 12/35
# 100/100 [==============================] - 93s 926ms/step - loss: 0.2571 - binary_accuracy: 0.8961 - balanced_acc: 0.8952 - f1: 0.8786 - f2: 0.8451 - recall: 0.8219 - specificity: 0.9649 - precision: 0.9506 - auc: 0.9621 - val_loss: 3.3729 - val_binary_accuracy: 0.8188 - val_balanced_acc: 0.8128 - val_f1: 0.7702 - val_f2: 0.6980 - val_recall: 0.6580 - val_specificity: 0.9674 - val_precision: 0.9484 - val_auc: 0.8551
# Epoch 13/35
# 100/100 [==============================] - 94s 935ms/step - loss: 0.2215 - binary_accuracy: 0.9061 - balanced_acc: 0.9041 - f1: 0.8921 - f2: 0.8591 - recall: 0.8363 - specificity: 0.9683 - precision: 0.9587 - auc: 0.9681 - val_loss: 0.3812 - val_binary_accuracy: 0.8703 - val_balanced_acc: 0.8635 - val_f1: 0.8426 - val_f2: 0.7810 - val_recall: 0.7450 - val_specificity: 0.9816 - val_precision: 0.9740 - val_auc: 0.9348
# Epoch 14/35
# 100/100 [==============================] - 91s 907ms/step - loss: 0.1720 - binary_accuracy: 0.9199 - balanced_acc: 0.9180 - f1: 0.9053 - f2: 0.8736 - recall: 0.8542 - specificity: 0.9813 - precision: 0.9727 - auc: 0.9810 - val_loss: 0.2990 - val_binary_accuracy: 0.8766 - val_balanced_acc: 0.8732 - val_f1: 0.8600 - val_f2: 0.8367 - val_recall: 0.8221 - val_specificity: 0.9242 - val_precision: 0.9041 - val_auc: 0.9594
# Epoch 15/35
# 100/100 [==============================] - 94s 939ms/step - loss: 0.1834 - binary_accuracy: 0.9203 - balanced_acc: 0.9203 - f1: 0.9102 - f2: 0.8959 - recall: 0.8862 - specificity: 0.9522 - precision: 0.9413 - auc: 0.9794 - val_loss: 0.4195 - val_binary_accuracy: 0.8953 - val_balanced_acc: 0.8895 - val_f1: 0.8754 - val_f2: 0.8420 - val_recall: 0.8261 - val_specificity: 0.9574 - val_precision: 0.9427 - val_auc: 0.9419
# Epoch 16/35
# 100/100 [==============================] - 93s 926ms/step - loss: 0.1527 - binary_accuracy: 0.9275 - balanced_acc: 0.9264 - f1: 0.9165 - f2: 0.8885 - recall: 0.8691 - specificity: 0.9812 - precision: 0.9738 - auc: 0.9845 - val_loss: 0.2813 - val_binary_accuracy: 0.8938 - val_balanced_acc: 0.8885 - val_f1: 0.8754 - val_f2: 0.8339 - val_recall: 0.8094 - val_specificity: 0.9684 - val_precision: 0.9565 - val_auc: 0.9630
# Epoch 17/35
# 100/100 [==============================] - 94s 944ms/step - loss: 0.1345 - binary_accuracy: 0.9375 - balanced_acc: 0.9361 - f1: 0.9294 - f2: 0.9111 - recall: 0.8993 - specificity: 0.9723 - precision: 0.9659 - auc: 0.9887 - val_loss: 0.3896 - val_binary_accuracy: 0.8406 - val_balanced_acc: 0.8360 - val_f1: 0.8033 - val_f2: 0.7378 - val_recall: 0.6933 - val_specificity: 0.9713 - val_precision: 0.9541 - val_auc: 0.9424
# Epoch 18/35
# 100/100 [==============================] - 92s 916ms/step - loss: 0.1313 - binary_accuracy: 0.9473 - balanced_acc: 0.9468 - f1: 0.9410 - f2: 0.9332 - recall: 0.9289 - specificity: 0.9647 - precision: 0.9582 - auc: 0.9889 - val_loss: 0.3154 - val_binary_accuracy: 0.8687 - val_balanced_acc: 0.8654 - val_f1: 0.8566 - val_f2: 0.8358 - val_recall: 0.8252 - val_specificity: 0.9079 - val_precision: 0.8947 - val_auc: 0.9565
# Epoch 19/35
# 100/100 [==============================] - 91s 914ms/step - loss: 0.1608 - binary_accuracy: 0.9246 - balanced_acc: 0.9290 - f1: 0.9164 - f2: 0.9212 - recall: 0.9221 - specificity: 0.9307 - precision: 0.9184 - auc: 0.9835 - val_loss: 0.4674 - val_binary_accuracy: 0.8797 - val_balanced_acc: 0.8771 - val_f1: 0.8651 - val_f2: 0.8383 - val_recall: 0.8206 - val_specificity: 0.9323 - val_precision: 0.9148 - val_auc: 0.9476
# Epoch 20/35
# 100/100 [==============================] - 94s 938ms/step - loss: 0.1346 - binary_accuracy: 0.9400 - balanced_acc: 0.9439 - f1: 0.9344 - f2: 0.9334 - recall: 0.9280 - specificity: 0.9535 - precision: 0.9437 - auc: 0.9883 - val_loss: 0.3432 - val_binary_accuracy: 0.9031 - val_balanced_acc: 0.9011 - val_f1: 0.8927 - val_f2: 0.8764 - val_recall: 0.8671 - val_specificity: 0.9357 - val_precision: 0.9223 - val_auc: 0.9644
# Epoch 21/35
# 100/100 [==============================] - 95s 949ms/step - loss: 0.1402 - binary_accuracy: 0.9381 - balanced_acc: 0.9386 - f1: 0.9311 - f2: 0.9211 - recall: 0.9126 - specificity: 0.9616 - precision: 0.9540 - auc: 0.9872 - val_loss: 0.2963 - val_binary_accuracy: 0.9031 - val_balanced_acc: 0.9035 - val_f1: 0.9006 - val_f2: 0.9163 - val_recall: 0.9267 - val_specificity: 0.8794 - val_precision: 0.8742 - val_auc: 0.9664
# Epoch 22/35
# 100/100 [==============================] - 91s 915ms/step - loss: 0.1119 - binary_accuracy: 0.9504 - balanced_acc: 0.9514 - f1: 0.9461 - f2: 0.9496 - recall: 0.9513 - specificity: 0.9500 - precision: 0.9437 - auc: 0.9922 - val_loss: 0.2962 - val_binary_accuracy: 0.9000 - val_balanced_acc: 0.8976 - val_f1: 0.8910 - val_f2: 0.8680 - val_recall: 0.8520 - val_specificity: 0.9411 - val_precision: 0.9317 - val_auc: 0.9678
# Epoch 23/35
# 100/100 [==============================] - 92s 915ms/step - loss: 0.0973 - binary_accuracy: 0.9589 - balanced_acc: 0.9611 - f1: 0.9554 - f2: 0.9531 - recall: 0.9487 - specificity: 0.9698 - precision: 0.9635 - auc: 0.9942 - val_loss: 0.3220 - val_binary_accuracy: 0.9047 - val_balanced_acc: 0.8984 - val_f1: 0.8873 - val_f2: 0.8590 - val_recall: 0.8472 - val_specificity: 0.9552 - val_precision: 0.9444 - val_auc: 0.9652
# Epoch 24/35
# 100/100 [==============================] - 94s 936ms/step - loss: 0.0962 - binary_accuracy: 0.9592 - balanced_acc: 0.9592 - f1: 0.9553 - f2: 0.9507 - recall: 0.9472 - specificity: 0.9700 - precision: 0.9653 - auc: 0.9939 - val_loss: 0.2808 - val_binary_accuracy: 0.9125 - val_balanced_acc: 0.9102 - val_f1: 0.9049 - val_f2: 0.9008 - val_recall: 0.8983 - val_specificity: 0.9220 - val_precision: 0.9107 - val_auc: 0.9681
# Epoch 25/35
# 100/100 [==============================] - 94s 937ms/step - loss: 0.0953 - binary_accuracy: 0.9591 - balanced_acc: 0.9612 - f1: 0.9550 - f2: 0.9574 - recall: 0.9575 - specificity: 0.9628 - precision: 0.9556 - auc: 0.9943 - val_loss: 0.2533 - val_binary_accuracy: 0.9187 - val_balanced_acc: 0.9182 - val_f1: 0.9088 - val_f2: 0.9005 - val_recall: 0.8970 - val_specificity: 0.9406 - val_precision: 0.9278 - val_auc: 0.9731
# Epoch 26/35
# 100/100 [==============================] - 93s 926ms/step - loss: 0.0894 - binary_accuracy: 0.9633 - balanced_acc: 0.9657 - f1: 0.9604 - f2: 0.9635 - recall: 0.9633 - specificity: 0.9652 - precision: 0.9588 - auc: 0.9948 - val_loss: 0.2962 - val_binary_accuracy: 0.9125 - val_balanced_acc: 0.9095 - val_f1: 0.8990 - val_f2: 0.8846 - val_recall: 0.8800 - val_specificity: 0.9433 - val_precision: 0.9296 - val_auc: 0.9681
# Epoch 27/35
# 100/100 [==============================] - 92s 921ms/step - loss: 0.0939 - binary_accuracy: 0.9598 - balanced_acc: 0.9606 - f1: 0.9557 - f2: 0.9561 - recall: 0.9560 - specificity: 0.9642 - precision: 0.9585 - auc: 0.9943 - val_loss: 0.3097 - val_binary_accuracy: 0.9172 - val_balanced_acc: 0.9165 - val_f1: 0.9111 - val_f2: 0.9017 - val_recall: 0.8940 - val_specificity: 0.9371 - val_precision: 0.9278 - val_auc: 0.9675
# Epoch 28/35
# 100/100 [==============================] - 93s 928ms/step - loss: 0.0837 - binary_accuracy: 0.9651 - balanced_acc: 0.9661 - f1: 0.9621 - f2: 0.9648 - recall: 0.9660 - specificity: 0.9650 - precision: 0.9602 - auc: 0.9954 - val_loss: 0.2977 - val_binary_accuracy: 0.9109 - val_balanced_acc: 0.9087 - val_f1: 0.9012 - val_f2: 0.8859 - val_recall: 0.8779 - val_specificity: 0.9411 - val_precision: 0.9301 - val_auc: 0.9681
# Epoch 29/35
# 100/100 [==============================] - 92s 916ms/step - loss: 0.0754 - binary_accuracy: 0.9680 - balanced_acc: 0.9682 - f1: 0.9639 - f2: 0.9612 - recall: 0.9599 - specificity: 0.9765 - precision: 0.9716 - auc: 0.9964 - val_loss: 0.2932 - val_binary_accuracy: 0.9062 - val_balanced_acc: 0.9070 - val_f1: 0.8986 - val_f2: 0.9044 - val_recall: 0.9103 - val_specificity: 0.9049 - val_precision: 0.8925 - val_auc: 0.9674
# Epoch 30/35
# 100/100 [==============================] - 94s 944ms/step - loss: 0.0760 - binary_accuracy: 0.9699 - balanced_acc: 0.9708 - f1: 0.9669 - f2: 0.9688 - recall: 0.9699 - specificity: 0.9709 - precision: 0.9660 - auc: 0.9958 - val_loss: 0.2965 - val_binary_accuracy: 0.9109 - val_balanced_acc: 0.9105 - val_f1: 0.9051 - val_f2: 0.8889 - val_recall: 0.8762 - val_specificity: 0.9423 - val_precision: 0.9340 - val_auc: 0.9698
# Epoch 31/35
# 100/100 [==============================] - 92s 919ms/step - loss: 0.0682 - binary_accuracy: 0.9695 - balanced_acc: 0.9715 - f1: 0.9670 - f2: 0.9656 - recall: 0.9620 - specificity: 0.9778 - precision: 0.9730 - auc: 0.9969 - val_loss: 0.2632 - val_binary_accuracy: 0.9156 - val_balanced_acc: 0.9135 - val_f1: 0.9050 - val_f2: 0.8911 - val_recall: 0.8810 - val_specificity: 0.9446 - val_precision: 0.9317 - val_auc: 0.9724
# Epoch 32/35
# 100/100 [==============================] - 92s 923ms/step - loss: 0.0721 - binary_accuracy: 0.9686 - balanced_acc: 0.9691 - f1: 0.9651 - f2: 0.9648 - recall: 0.9648 - specificity: 0.9731 - precision: 0.9686 - auc: 0.9968 - val_loss: 0.3026 - val_binary_accuracy: 0.9203 - val_balanced_acc: 0.9181 - val_f1: 0.9127 - val_f2: 0.8994 - val_recall: 0.8881 - val_specificity: 0.9451 - val_precision: 0.9357 - val_auc: 0.9668
# Epoch 33/35
# 100/100 [==============================] - 92s 920ms/step - loss: 0.0697 - binary_accuracy: 0.9711 - balanced_acc: 0.9717 - f1: 0.9657 - f2: 0.9688 - recall: 0.9720 - specificity: 0.9719 - precision: 0.9668 - auc: 0.9971 - val_loss: 0.3157 - val_binary_accuracy: 0.9109 - val_balanced_acc: 0.9084 - val_f1: 0.9032 - val_f2: 0.8876 - val_recall: 0.8775 - val_specificity: 0.9388 - val_precision: 0.9298 - val_auc: 0.9658
# Epoch 34/35
# 100/100 [==============================] - 91s 914ms/step - loss: 0.0769 - binary_accuracy: 0.9683 - balanced_acc: 0.9694 - f1: 0.9647 - f2: 0.9650 - recall: 0.9641 - specificity: 0.9731 - precision: 0.9686 - auc: 0.9960 - val_loss: 0.2978 - val_binary_accuracy: 0.9094 - val_balanced_acc: 0.9089 - val_f1: 0.9035 - val_f2: 0.8952 - val_recall: 0.8907 - val_specificity: 0.9280 - val_precision: 0.9203 - val_auc: 0.9693
# Epoch 35/35
# 100/100 [==============================] - 95s 950ms/step - loss: 0.0655 - binary_accuracy: 0.9711 - balanced_acc: 0.9715 - f1: 0.9684 - f2: 0.9712 - recall: 0.9727 - specificity: 0.9696 - precision: 0.9662 - auc: 0.9973 - val_loss: 0.3265 - val_binary_accuracy: 0.9000 - val_balanced_acc: 0.8985 - val_f1: 0.8886 - val_f2: 0.8768 - val_recall: 0.8717 - val_specificity: 0.9275 - val_precision: 0.9138 - val_auc: 0.9659

# %%
# %cd drive/My\ Drive
model.save("CVT/saved_models/xception")
# Out:
# /content/drive/My Drive
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: CVT/saved_models/xception/assets

# %% [markdown]
# **Training and Validation Metrics**

# %%
graph_metrics(history)

# %% [markdown]
# **Make Predictions**

# %%
# test_generator = test2_generator
test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(
        TEST_DIR,
        target_size=IMAGE_SIZE,
        shuffle=False,
        class_mode='binary'
    )
y_true = 1 - test_generator.classes
prediction = (1 - model.predict(test_generator))
y_pred = [1 * (x[0]>=.25) for x in prediction]
# Out:
# Found 690 images belonging to 2 classes.

# %% [markdown]
# **Visualize Predictions**

# %%
index = 0
while index < len(prediction):
  probability = prediction[index]
  image_path =  TEST_DIR + "/" +test_generator.filenames[index]
  image = mpimg.imread(image_path, 0)
  #BGR TO RGB conversion using CV2
  image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
  pixels = np.array(image)
  plt.imshow(pixels)
  print("prob:{}".format(probability))
  print(test_generator.filenames[index])
    
  plt.title('%.2f' % ((probability)*100) + '% COVID')
  plt.show()
  index+=random.randint(50,150)
# Out:
# prob:[0.9999922]
# COVID/2019-novel-Coronavirus-severe-adult-respiratory-dist_2020_International-Jour-p3-89%1.png
# prob:[1.]
# COVID/Covid (265).png
# prob:[0.9998406]
# COVID/Covid (877).png
# prob:[0.43182236]
# COVID/img639.jpg
# prob:[0.9999948]
# NonCOVID/35%2.jpg
# prob:[0.]
# NonCOVID/Non-Covid (315).png
# prob:[0.00058472]
# NonCOVID/Non-Covid (877).png
# prob:[0.]
# NonCOVID/nor_15_img_2.jpg

# %% [markdown]
# **Evaluate Model**

# %%
print(metrics.classification_report(y_true, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.87      0.90       325
#            1       0.89      0.95      0.92       365
#
#     accuracy                           0.91       690
#    macro avg       0.91      0.91      0.91       690
# weighted avg       0.91      0.91      0.91       690

# %% [markdown]
# **In-Depth Metrics Report**
# see https://en.wikipedia.org/wiki/Confusion_matrix

# %%
def matrix_metrix(y_true, y_pred):
    CM = metrics.confusion_matrix(y_true , y_pred)
    TN = CM[0][0]
    FN = CM[1][0] 
    TP = CM[1][1]
    FP = CM[0][1]
    Population = TN+FN+TP+FP
    Prevalence = round( (TP+FP) / Population,3)
    Accuracy   = round( (TP+TN) / Population,3)
    Precision  = round( TP / (TP+FP),3 )
    NPV        = round( TN / (TN+FN),3 )
    FDR        = round( FP / (TP+FP),3 )
    FOR        = round( FN / (TN+FN),3 ) 
    check_Pos  = Precision + FDR
    check_Neg  = NPV + FOR
    Recall     = round( TP / (TP+FN),3 )
    FPR        = round( FP / (TN+FP),3 )
    Specificity = 1 - FPR
    FNR        = round( FN / (TP+FN),3)
    TNR        = round( TN / (TN+FP),3 ) 
    check_Pos2 = Recall + FNR
    check_Neg2 = FPR + TNR
    LRPos      = round( Recall/FPR,3 ) 
    LRNeg      = round( FNR / TNR ,3 )
    DOR        = round( LRPos/LRNeg)
    F1         = round ( 2 * ((Precision*Recall)/(Precision+Recall)),4)
    F2      = round ( (1+2**2)*((Precision*Recall)/((2**2 * Precision)+ Recall)) ,4)
    MCC        = round ( ((TP*TN)-(FP*FN))/math.sqrt((TP+FP)*(TP+FN)*(TN+FP)*(TN+FN))  ,4)
    BM         = Recall+TNR-1
    MK         = Precision+NPV-1
    AUC = round(roc_auc_score(y_true, y_pred),3)

    met_dict = {
   'TP': TP,'TN':TN,'FP':FP,  'FN':FN,   'Prevalence':Prevalence, 
     'Accuracy':Accuracy,   'Precision':Precision,'Recall':Recall,
    'F1':F1,  'F2':F2, 'AUC':AUC, 'NPV':NPV,'FPR':FPR,
   'TNR':Specificity,  'FNR':FNR, 'TNR':TNR,'FDR':FDR,'FOR':FOR,'check_Pos':check_Pos,
   'check_Neg':check_Neg,  'check_Pos2':check_Pos2, 'check_Neg2':check_Neg2, 'LR+':LRPos,
    'LR-':LRNeg,  'DOR':DOR, 'MCC':MCC,'BM':BM,'MK':MK 
   }  

    return met_dict

for key, value in matrix_metrix(y_true, y_pred).items(): 
    print("{:<10} {:<10}".format(key, value))
# Out:
# TP         345
# TN         284
# FP         41
# FN         20
# Prevalence 0.559
# Accuracy   0.912
# Precision  0.894
# Recall     0.945
# F1         0.9188
# F2         0.9343
# AUC        0.91
# NPV        0.934
# FPR        0.126
# TNR        0.874
# FNR        0.055
# FDR        0.106
# FOR        0.066
# check_Pos  1.0
# check_Neg  1.0
# check_Pos2 1.0
# check_Neg2 1.0
# LR+        7.5
# LR-        0.063
# DOR        119.0
# MCC        0.8235
# BM         0.819
# MK         0.8280000000000001

# %% [markdown]
# **Confusion Matrix**

# %%
def plot_confusion_matrix(cm, classes,
    normalize=False,
    title='Confusion matrix',
    cmap=plt.cm.Blues):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')
    
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt), fontsize= 20,
                 horizontalalignment="center",
                 color="yellow" if cm[i, j] > thresh else "red")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()
cm=metrics.confusion_matrix(y_true,y_pred)
plot_confusion_matrix(cm=cm, classes=['NON-COVID', 'COVID'], title='Confusion Matrix')
plot_confusion_matrix(cm=cm, classes=['NON-COVID', 'COVID'], title='Confusion Matrix', normalize=True)
# Out:
# Confusion matrix, without normalization
# Normalized confusion matrix

# %% [markdown]
# **ROC Curve**

# %%
#ROC Implementation
def get_roc_curve(y_true, y_pred):
  print("AUC: " + str(metrics.roc_auc_score(y_true, y_pred)))
  fpr, tpr, thresholds = roc_curve(y_true, y_pred)
  # print(fpr)
  # print(tpr)
  pyplot.plot(fpr, tpr, linestyle='--', label='ROC curve')
  pyplot.xlabel('False Positive Rate')
  pyplot.ylabel('True Positive Rate')
  pyplot.legend()
  pyplot.show()
  
get_roc_curve(y_true, prediction)
# Out:
# AUC: 0.9716417281348788

# %% [markdown]
# **Precision-Recall Curve**

# %%
def get_pr_curve(y_true, y_pred):
  print("Average Precision: " +  str(sklearn.metrics.average_precision_score(y_true, y_pred)))
  precision, recall, thresholds = sklearn.metrics.precision_recall_curve(y_true, y_pred)
  pyplot.plot(recall, precision, linestyle='--', label='Precision versus Recall')
  pyplot.xlabel('Recall')
  pyplot.ylabel('Precision')
  pyplot.legend()
  pyplot.show()

get_pr_curve(y_true, prediction)
# Out:
# Average Precision: 0.9735899215635605

# %% [markdown]
# **Compare Metrics at Different Classification Thresholds**

# %%
thresholds = [round(i * .01, 2) for i in range(1,100)]
def metric_against_thresholds(metric):
    vals = []
    for t in thresholds:
      y_pred = [1 * (x>=t) for x in prediction]
    
      vals.append(float(matrix_metrix(y_true, y_pred)[metric]))

    return vals

def plot_metrics_against_thresholds(desired_metrics= ["Accuracy","Precision", "Recall", "F1", "F2"]):
  pyplot.figure(figsize=(14,14))
  pyplot.xlabel("Classification Threshold", fontsize=15)
  pyplot.ylabel("Metric Value", fontsize=15)
  for i in range(len(desired_metrics)):
    pyplot.plot(thresholds, metric_against_thresholds(desired_metrics[i]), lw=2, label=desired_metrics[i])
  pyplot.legend(title="Metrics", fontsize='large')
  pyplot.grid()
  pyplot.show()
plot_metrics_against_thresholds()

# %% [markdown]
# **Optimal Cutoffs**
#
# see https://www.hindawi.com/journals/cmmm/2017/3762651/

# %%
def get_optimal_cutoffs():
  TN, FP, FN, TP = metrics.confusion_matrix(y_true,y_pred).ravel()
  sensitivity = round( TP / (TP+FN),2 )
  specificity = round( TN / (TN+FP),2 )
  auc = metrics.roc_auc_score(y_true, y_pred)

  youden = sensitivity + specificity - 1
  print("youden: " + str(youden))

  closest_to_01 =  np.sqrt(((1 - sensitivity)**2) + ((1 - specificity)**2))
  print("Closest to (0,1): " + str(np.around(closest_to_01, decimals = 3)))

  concordance_probability = sensitivity * specificity
  print("Concordance Probability: " + str((np.around(concordance_probability, decimals = 3))))

  index_of_union = np.abs(sensitivity - auc) + np.abs(specificity - auc)
  print("Index of Union: " + str((np.around(index_of_union, decimals = 3))))

get_optimal_cutoffs()
# Out:
# youden: 0.8199999999999998
# Closest to (0,1): 0.139
# Concordance Probability: 0.826
# Index of Union: 0.08
